# %%
import os
import sys
import math
import copy 
import torch 
import random
DEBUG = False
import numpy as np
import torch_sparse
import pandas as pd 
import pickle as pkl
from tqdm import tqdm
from time import time
import networkx as nx
from dgl import DGLGraph
from scipy import linalg
from pathlib import Path
from torch import Tensor
import scipy.sparse as sp
from random import randint
from dgl import transforms
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
from scipy import sparse, stats
from scipy.sparse import csgraph
from scipy.sparse import csr_matrix
from dgl import from_networkx, DGLGraph
from torch_geometric.utils import scatter
from dgl.data import citation_graph as citegrh
from torch_geometric.typing import SparseTensor
from torch_geometric.utils import to_undirected
from torch_geometric.utils import remove_self_loops
from sklearn.metrics.pairwise import cosine_similarity
# from ipynb.fs.full.Dataset import get_data_from_dataset
# from ipynb.fs.full.Dataset import get_data_from_dataset,train_val_test_mask
from ogb.nodeproppred import Evaluator, PygNodePropPredDataset
from typing import Callable, List, NamedTuple, Optional, Tuple, Union
from torch_geometric.utils import add_self_loops,add_remaining_self_loops
# from ipynb.fs.full.SpectralSparsifier import EffectiveResistance, LocalEffectiveResistance, get_sparse_adj_matrix

# %%
import numpy as np
import torch
import pickle as pkl
import sys
import networkx as nx
import numpy as np
import scipy.sparse as sp

import argparse
import time
from time import localtime
import torch
import torch.nn.functional as F
from dgl import DGLGraph
from dgl.data import register_data_args, load_data
import random
from torch.backends import cudnn
import networkx as nx
import numpy as np
import torch
import torch.nn as nn
import dgl.function as fn
from dgl.nn.pytorch import edge_softmax
import numpy as np
import torch.nn.functional as F

import torch
import torch.nn as nn
import dgl.function as fn
from dgl.nn.pytorch import edge_softmax
import numpy as np
import torch.nn.functional as F

# %%
import torch
from contextlib import contextmanager
import subprocess
import re

# # At the start of your script
# torch.cuda.reset_peak_memory_stats()  # Reset memory statistics

# # ... your training loop ...

# # Get max memory used (in bytes)
# max_memory = torch.cuda.max_memory_allocated()
# print(f"Max GPU memory used: {max_memory / 1024**2:.2f} MB")

# # Optionally, get memory by device if using multiple GPUs
# for i in range(torch.cuda.device_count()):
#     max_memory = torch.cuda.max_memory_allocated(i)
#     print(f"Max GPU memory used on device {i}: {max_memory / 1024**2:.2f} MB")


# @contextmanager
# def track_memory_usage(description="", device=None):
#     if device is None:
#         device = torch.cuda.current_device()
#     torch.cuda.synchronize(device)
#     torch.cuda.reset_peak_memory_stats(device)
#     yield
#     torch.cuda.synchronize(device)
#     max_memory = torch.cuda.max_memory_allocated(device)
#     print(f"{description} Max GPU memory used: {max_memory / 1024**2:.2f} MB")
    
def get_gpu_memory_usage():
    result = subprocess.check_output(['nvidia-smi', '--query-gpu=memory.used', '--format=csv,nounits,noheader'])
    memory_usage = [int(x) for x in result.decode('utf-8').strip().split('\n')]
    return memory_usage

# Call this periodically during training to track memory usage
get_gpu_memory_usage()
# Out:
# [750]

# %%
import DeviceDir

DIR, RESULTS_DIR = DeviceDir.get_directory()
device, NUM_PROCESSORS = DeviceDir.get_device()

# %%
from ipynb.fs.full.SGSLoadDataset import LOAD_DATASET, train_val_test_mask

DATASET_NAME = "moon"
data, dataset  = LOAD_DATASET(DIR, DATASET_NAME)
num_classes = max(data.y).item()+1
# if DATASET_NAME == "wiki":
#     data = train_val_test_mask(data, train=0.2, val=0.4, test=0.4, random_state=False)
# data
if len(data.train_mask.shape)>1:
    index = 0
    data.train_mask = data.train_mask[:,index]
    data.val_mask = data.val_mask[:,index]
    if DATASET_NAME == 'wiki':
        None
    else:
        data.test_mask = data.test_mask[:,index]
    
data
# Out:
# moon N: 100 E: 596 F: 2 C: 2 d: 5.96 lr: 0.20 i: False s: False u: True
# Data(x=[100, 2], edge_index=[2, 596], y=[100], train_mask=[100], val_mask=[100], test_mask=[100], edge_weight=[596, 1])

# %%
from ipynb.fs.full.Moon import MoonDataset

DATASET_NAME = "moon"
dataset = MoonDataset(n_samples=150, degree=4, train=0.3, h=0.2)
data = dataset[0]

if "train_mask" not in data.__dict__["_store"]:
    data = train_val_test_mask(data, train=0.3, val=0.3, test=0.4, random_state=False)

num_classes = max(data.y).item() + 1

# %%
sig = nn.Sigmoid()
hardtanh = nn.Hardtanh(0,1)
gamma = -0.1
zeta = 1.1
beta = 0.66
eps = 1e-20
const1 = beta*np.log(-gamma/zeta + eps)

def l0_train(logAlpha, min, max):
    U = torch.rand(logAlpha.size()).type_as(logAlpha) + eps
    s = sig((torch.log(U / (1 - U)) + logAlpha) / beta)
    s_bar = s * (zeta - gamma) + gamma
    mask = F.hardtanh(s_bar, min, max)
    return mask

def l0_test(logAlpha, min, max):
    s = sig(logAlpha/beta)
    s_bar = s * (zeta - gamma) + gamma
    mask = F.hardtanh(s_bar, min, max)
    return mask

def get_loss2(logAlpha):
    return sig(logAlpha - const1)


class GraphAttention(nn.Module):
    def __init__(self,
                 g,
                 in_dim,
                 out_dim,
                 num_heads,
                 feat_drop,
                 attn_drop,
                 alpha,
                 bias_l0,
                 residual=False,l0=0, min=0):
        super(GraphAttention, self).__init__()
        self.g = g
        self.num_heads = num_heads
        self.fc = nn.Linear(in_dim, num_heads * out_dim, bias=False)
        if feat_drop:
            self.feat_drop = nn.Dropout(feat_drop)
        else:
            self.feat_drop = lambda x : x
        if attn_drop:
            self.attn_drop = nn.Dropout(attn_drop)
        else:
            self.attn_drop = lambda x : x
        self.attn_l = nn.Parameter(torch.Tensor(size=(1, 1, out_dim)))
        self.attn_r = nn.Parameter(torch.Tensor(size=(1, 1, out_dim)))
        self.bias_l0 = nn.Parameter(torch.FloatTensor([bias_l0]))

        nn.init.xavier_normal_(self.fc.weight.data, gain=1.414)
        nn.init.xavier_normal_(self.attn_l.data, gain=1.414)
        nn.init.xavier_normal_(self.attn_r.data, gain=1.414)
        self.leaky_relu = nn.LeakyReLU(alpha)
        self.softmax = edge_softmax
        self.residual = residual
        self.num = 0
        self.l0 = l0
        self.loss = 0
        self.dis = []
        self.min=min
        if residual:
            if in_dim != out_dim:
                self.res_fc = nn.Linear(in_dim, num_heads * out_dim, bias=False)
                nn.init.xavier_normal_(self.res_fc.weight.data, gain=1.414)
            else:
                self.res_fc = None

    def forward(self, inputs, edges="__ALL__", skip=0):
        self.loss = 0
        # prepare
        h = self.feat_drop(inputs)  # NxD
        ft = self.fc(h).reshape((h.shape[0], self.num_heads, -1))  # NxHxD'
        a1 = (ft * self.attn_l).sum(dim=-1).unsqueeze(-1) # N x H x 1
        a2 = (ft * self.attn_r).sum(dim=-1).unsqueeze(-1) # N x H x 1
      
        self.g.ndata.update({'ft' : ft, 'a1' : a1, 'a2' : a2})

        if skip == 0:
            # 1. compute edge attention
            self.g.apply_edges(self.edge_attention, edges)

            # 2. compute softmax
            if self.l0 == 1:
                ind = self.g.nodes()
                self.g.apply_edges(self.loop, edges=(ind, ind))

            self.edge_softmax()

            if self.l0 == 1:
                self.g.apply_edges(self.norm)

        # 2. compute the aggregated node features scaled by the dropped,
            edges = self.g.edata['a'].squeeze().nonzero().squeeze()


        self.g.edata['a_drop'] = self.attn_drop(self.g.edata['a'])
        self.num = (self.g.edata['a'] > 0).sum()
        self.g.update_all(fn.u_mul_e('ft', 'a_drop', 'ft'), fn.sum('ft', 'ft'))
        ret = self.g.ndata['ft']

        # 4. residual
        if self.residual:
            if self.res_fc is not None:
                resval = self.res_fc(h).reshape((h.shape[0], self.num_heads, -1))  # NxHxD'
            else:
                resval = torch.unsqueeze(h, 1)  # Nx1xD'
            ret = resval + ret
        return ret, edges

    def edge_attention(self, edges):
        # an edge UDF to compute unnormalized attention values from src and dst
        if self.l0 == 0:
            m = self.leaky_relu(edges.src['a1'] + edges.dst['a2'])
        else:
            tmp = edges.src['a1'] + edges.dst['a2']
            logits = tmp + self.bias_l0

            if self.training:
                m = l0_train(logits, 0, 1)
            else:
                m = l0_test(logits, 0, 1)
            self.loss = get_loss2(logits[:,0,:]).sum()
        return {'a': m}

    def norm(self, edges):
        # normalize attention
        a = edges.data['a'] / edges.dst['z']
        return {'a' : a}

    def loop(self, edges):
        # set attention to itself as 1
        return {'a': torch.pow(edges.data['a'], 0)}

    def normalize(self, logits):
        self._logits_name = "_logits"
        self._normalizer_name = "_norm"
        self.g.edata[self._logits_name] = logits
        self.g.update_all(fn.copy_edge(self._logits_name, self._logits_name),
                         fn.sum(self._logits_name, self._normalizer_name))
        return self.g.edata.pop(self._logits_name), self.g.ndata.pop(self._normalizer_name)

    def edge_softmax(self):

        if self.l0 == 0:
            scores = self.softmax(self.g, self.g.edata.pop('a'))
        else:
            scores, normalizer = self.normalize(self.g.edata.pop('a'))
            self.g.ndata['z'] = normalizer[:,0,:].unsqueeze(1)

        self.g.edata['a'] = scores[:,0,:].unsqueeze(1)

class GAT(nn.Module):
    def __init__(self,
                 g,
                 num_layers,
                 in_dim,
                 num_hidden,
                 num_classes,
                 heads,
                 activation,
                 feat_drop,
                 attn_drop,
                 alpha,
                 bias_l0,
                 residual, l0=0):
        super(GAT, self).__init__()
        self.g = g
        self.num_layers = num_layers
        self.gat_layers = nn.ModuleList()
        self.activation = activation
        # input projection (no residual)
        self.gat_layers.append(GraphAttention(
            g, in_dim, num_hidden, heads[0], feat_drop, attn_drop, alpha,bias_l0, False, l0=l0, min=0))
        # hidden layers
        for l in range(1, num_layers):
            # due to multi-head, the in_dim = num_hidden * num_heads
            self.gat_layers.append(GraphAttention(
                g, num_hidden * heads[l-1], num_hidden, heads[l],
                feat_drop, attn_drop, alpha,bias_l0, residual, l0=l0, min=0))
        # output projection
        self.gat_layers.append(GraphAttention(
            g, num_hidden * heads[-2], num_classes, heads[-1],
            feat_drop, attn_drop, alpha,bias_l0, residual, l0=l0))


    def forward(self, inputs):

        h = inputs
        edges = "__ALL__"
        h, edges = self.gat_layers[0](h, edges)
        h = self.activation(h.flatten(1))
        for l in range(1, self.num_layers):
            h, _= self.gat_layers[l](h, edges, skip=1)
            h = self.activation(h.flatten(1))

        # output projection
        logits,_ = self.gat_layers[-1](h, edges, skip=1)
        logits = logits.mean(1)
        return logits

# %% [markdown]
# utils .py

# %%
class EarlyStopping:
    def __init__(self, patience=10):
        self.patience = patience
        self.counter = 0
        self.best_score = None
        self.early_stop = False

    def step(self, acc, model):
        score = acc
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(model)
        elif score < self.best_score:
            self.counter += 1
            # print('EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(model)
            self.counter = 0
        return self.early_stop

    def save_checkpoint(self, model):
        '''Saves model when validation loss decrease.'''
        torch.save(model.state_dict(), 'es_checkpoint.pt')

# %% [markdown]
# GAT . py

# %%
from sklearn.metrics import f1_score

def accuracy(logits, labels):
#     _, indices = torch.max(logits, dim=1)
#     correct = torch.sum(indices == labels)
#     return correct.item() * 1.0 / len(labels)
    preds = logits.argmax(dim=1)
    f1 = f1_score(labels.cpu(), preds.cpu(), average='micro')
    return f1
    

def evaluate(model, features, labels, mask,loss_fcn):
    model.eval()
    with torch.no_grad():
        logits = model(features)
        logits = logits[mask]
        labels = labels[mask]
        loss_data = loss_fcn(logits, labels)
        return accuracy(logits, labels), loss_data

def set_seeds(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if gpu >= 0:
        torch.cuda.manual_seed(seed)
        cudnn.benchmark = False
        cudnn.deterministic = True

# %%
num_out_heads = 4
num_heads = 15
num_layers = 2
gpu = -1
l0 = 0
num_hidden = 128
residual = False 
idrop = 0.6
adrop = 0.6
lr = 0.005 
weight_decay = 5e-4
alpha = 0.2
early_stop = True 
fastmode = False 
seed = 123 
bias = 0 
loss_lo = 0 
syn_type = "scipy" 
self_loop = False 
sess ='default'
loss_l0  = 0
weight_decay = 0
l0 = 0

#data, dataset = get_data_from_dataset('cornell5')
epochs = 1500

data = data.to(device)

#features = torch.FloatTensor(data.x)
features = data.x
#labels = torch.LongTensor(data.y)
labels = data.y
train_mask = data.train_mask
val_mask = data.val_mask
test_mask = data.test_mask
num_feats = features.shape[1]
n_classes = max(data.y).item()+1
n_edges = data.num_edges
current_time = time.strftime('%d_%H:%M:%S', localtime())
print("HELLO WORLD")

print("""----Data statistics------'
    #Edges %d
    #Classes %d
    #Train samples %d
    #Val samples %d
    #Test samples %d""" %
        (n_edges, n_classes,
        train_mask.sum().item(),
        val_mask.sum().item(),
        test_mask.sum().item()))

cuda = True

import dgl
from dgl.data.utils import generate_mask_tensor

g = dgl.graph((data.edge_index[0], data.edge_index[1]), num_nodes=data.x.size(0))

# Add node features
g.ndata['feat'] = data.x
g.ndata['label'] = data.y
# g.ndata['train_mask'] = generate_mask_tensor(data.train_mask.numpy())
# g.ndata['val_mask'] = generate_mask_tensor(data.val_mask.numpy())
# g.ndata['test_mask'] = generate_mask_tensor(data.test_mask.numpy())

g.ndata['train_mask'] = data.train_mask
g.ndata['val_mask'] = data.val_mask
g.ndata['test_mask'] = data.test_mask


n_edges = g.number_of_edges()
heads = ([num_heads] * num_layers) + [num_out_heads]

model = GAT(g,
            num_layers,
            num_feats,
            num_hidden,
            n_classes,
            heads,
            F.elu,
            idrop,
            adrop,
            alpha,
            bias,
            residual,
            l0).to(device)
print(model)

if early_stop:
    stopper = EarlyStopping(patience=150)
loss_fcn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
dur = []
time_used = 0
# Out:
# HELLO WORLD
# ----Data statistics------'
#     #Edges 846
#     #Classes 2
#     #Train samples 45
#     #Val samples 45
#     #Test samples 60
# GAT(
#   (gat_layers): ModuleList(
#     (0): GraphAttention(
#       (fc): Linear(in_features=2, out_features=1920, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#     (1): GraphAttention(
#       (fc): Linear(in_features=1920, out_features=1920, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#     (2): GraphAttention(
#       (fc): Linear(in_features=1920, out_features=8, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
# )

# %%
model
# Out:
# GAT(
#   (gat_layers): ModuleList(
#     (0): GraphAttention(
#       (fc): Linear(in_features=2, out_features=1920, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#     (1): GraphAttention(
#       (fc): Linear(in_features=1920, out_features=1920, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#     (2): GraphAttention(
#       (fc): Linear(in_features=1920, out_features=8, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
# )

# %%
dur = []
best_test_f1 = 0

for epoch in range(epochs):
    
    model.train()
    t0 = time.time()

    # forward
    logits = model(features)
    loss = loss_fcn(logits[train_mask], labels[train_mask])

    loss_l0 = loss_l0*( model.gat_layers[0].loss)
    optimizer.zero_grad()
    (loss + loss_l0).backward()
    optimizer.step()
    dur.append(time.time() - t0)
    
#     print(get_gpu_memory_usage()[0], "MB")

    train_acc = accuracy(logits[train_mask], labels[train_mask])

    
    if fastmode:
        val_acc, loss = accuracy(logits[val_mask], labels[val_mask], loss_fcn)
    else:
        val_acc,_ = evaluate(model, features, labels, val_mask, loss_fcn)
#         if early_stop:
#             if stopper.step(val_acc, model):   
#                 break        
    
    print("Epoch {:05d} | Time(s) {:.4f} | Loss {:.4f} | TrainAcc {:.4f} |"
            " ValAcc {:.4f} | ETputs(KTEPS) {:.2f}".format(epoch, np.mean(dur), loss.item(), train_acc,
                    val_acc, n_edges / np.mean(dur) / 1000))
# print(dataset.name)


print("Time per epoch: ", np.mean(dur))
# Out:
# Epoch 00000 | Time(s) 0.6548 | Loss 0.7111 | TrainAcc 0.4222 | ValAcc 0.5333 | ETputs(KTEPS) 1.29
# Epoch 00001 | Time(s) 0.3300 | Loss 1.2951 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 2.56
# Epoch 00002 | Time(s) 0.2216 | Loss 6.8172 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 3.82
# Epoch 00003 | Time(s) 0.1674 | Loss 4.5660 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 5.05
# Epoch 00004 | Time(s) 0.1349 | Loss 1.6450 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 6.27
# Epoch 00005 | Time(s) 0.1132 | Loss 3.5487 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 7.47
# Epoch 00006 | Time(s) 0.0977 | Loss 2.9640 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 8.66
# Epoch 00007 | Time(s) 0.0861 | Loss 1.6096 | TrainAcc 0.4667 | ValAcc 0.7111 | ETputs(KTEPS) 9.83
# Epoch 00008 | Time(s) 0.0770 | Loss 1.0417 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 10.98
# Epoch 00009 | Time(s) 0.0698 | Loss 2.1910 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 12.12
# Epoch 00010 | Time(s) 0.0639 | Loss 1.0794 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 13.24
# Epoch 00011 | Time(s) 0.0589 | Loss 0.9621 | TrainAcc 0.6000 | ValAcc 0.5333 | ETputs(KTEPS) 14.35
# Epoch 00012 | Time(s) 0.0548 | Loss 0.7286 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 15.45
# Epoch 00013 | Time(s) 0.0512 | Loss 1.2718 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 16.53
# Epoch 00014 | Time(s) 0.0481 | Loss 1.0523 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 17.60
# Epoch 00015 | Time(s) 0.0454 | Loss 0.9095 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 18.65
# Epoch 00016 | Time(s) 0.0430 | Loss 0.7245 | TrainAcc 0.4889 | ValAcc 0.7111 | ETputs(KTEPS) 19.69
# Epoch 00017 | Time(s) 0.0408 | Loss 0.6955 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 20.71
# Epoch 00018 | Time(s) 0.0389 | Loss 0.6646 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 21.72
# Epoch 00019 | Time(s) 0.0372 | Loss 0.8669 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 22.71
# Epoch 00020 | Time(s) 0.0357 | Loss 0.9804 | TrainAcc 0.5333 | ValAcc 0.6889 | ETputs(KTEPS) 23.70
# Epoch 00021 | Time(s) 0.0343 | Loss 0.7364 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 24.67
# Epoch 00022 | Time(s) 0.0330 | Loss 0.7313 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 25.64
# Epoch 00023 | Time(s) 0.0318 | Loss 0.8369 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 26.58
# Epoch 00024 | Time(s) 0.0307 | Loss 0.7531 | TrainAcc 0.4889 | ValAcc 0.4889 | ETputs(KTEPS) 27.52
# Epoch 00025 | Time(s) 0.0297 | Loss 0.8420 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 28.45
# Epoch 00026 | Time(s) 0.0288 | Loss 0.7238 | TrainAcc 0.6000 | ValAcc 0.4667 | ETputs(KTEPS) 29.37
# Epoch 00027 | Time(s) 0.0279 | Loss 0.7480 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 30.27
# Epoch 00028 | Time(s) 0.0272 | Loss 0.7167 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 31.15
# Epoch 00029 | Time(s) 0.0264 | Loss 0.8173 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 32.04
# Epoch 00030 | Time(s) 0.0257 | Loss 0.7313 | TrainAcc 0.3333 | ValAcc 0.5333 | ETputs(KTEPS) 32.91
# Epoch 00031 | Time(s) 0.0250 | Loss 0.6921 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 33.78
# Epoch 00032 | Time(s) 0.0244 | Loss 0.6589 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 34.64
# Epoch 00033 | Time(s) 0.0238 | Loss 0.7668 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 35.49
# Epoch 00034 | Time(s) 0.0233 | Loss 0.7910 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 36.32
# Epoch 00035 | Time(s) 0.0228 | Loss 0.6839 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 37.14
# Epoch 00036 | Time(s) 0.0223 | Loss 0.7793 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 37.95
# Epoch 00037 | Time(s) 0.0218 | Loss 0.7338 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 38.75
# Epoch 00038 | Time(s) 0.0214 | Loss 0.8821 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 39.54
# Epoch 00039 | Time(s) 0.0210 | Loss 1.0206 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 40.32
# Epoch 00040 | Time(s) 0.0206 | Loss 0.7615 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 41.10
# Epoch 00041 | Time(s) 0.0202 | Loss 0.6887 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 41.87
# Epoch 00042 | Time(s) 0.0198 | Loss 1.0536 | TrainAcc 0.5556 | ValAcc 0.3556 | ETputs(KTEPS) 42.63
# Epoch 00043 | Time(s) 0.0195 | Loss 1.0104 | TrainAcc 0.4667 | ValAcc 0.4889 | ETputs(KTEPS) 43.39
# Epoch 00044 | Time(s) 0.0192 | Loss 0.7698 | TrainAcc 0.3111 | ValAcc 0.5333 | ETputs(KTEPS) 44.14
# Epoch 00045 | Time(s) 0.0189 | Loss 0.7119 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 44.88
# Epoch 00046 | Time(s) 0.0186 | Loss 0.9335 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 45.60
# Epoch 00047 | Time(s) 0.0183 | Loss 0.7098 | TrainAcc 0.6222 | ValAcc 0.6222 | ETputs(KTEPS) 46.32
# Epoch 00048 | Time(s) 0.0180 | Loss 0.6731 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 47.03
# Epoch 00049 | Time(s) 0.0177 | Loss 0.9016 | TrainAcc 0.3778 | ValAcc 0.4667 | ETputs(KTEPS) 47.73
# Epoch 00050 | Time(s) 0.0175 | Loss 0.8683 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 48.45
# Epoch 00051 | Time(s) 0.0172 | Loss 0.7503 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 49.14
# Epoch 00052 | Time(s) 0.0170 | Loss 0.9191 | TrainAcc 0.3556 | ValAcc 0.5333 | ETputs(KTEPS) 49.83
# Epoch 00053 | Time(s) 0.0167 | Loss 0.7942 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 50.51
# Epoch 00054 | Time(s) 0.0165 | Loss 0.8742 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 51.18
# Epoch 00055 | Time(s) 0.0163 | Loss 0.9975 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 51.83
# Epoch 00056 | Time(s) 0.0161 | Loss 0.8997 | TrainAcc 0.5333 | ValAcc 0.4444 | ETputs(KTEPS) 52.47
# Epoch 00057 | Time(s) 0.0159 | Loss 0.6933 | TrainAcc 0.6444 | ValAcc 0.4667 | ETputs(KTEPS) 53.12
# Epoch 00058 | Time(s) 0.0157 | Loss 0.7737 | TrainAcc 0.6000 | ValAcc 0.4667 | ETputs(KTEPS) 53.75
# Epoch 00059 | Time(s) 0.0156 | Loss 0.9357 | TrainAcc 0.3556 | ValAcc 0.4667 | ETputs(KTEPS) 54.39
# Epoch 00060 | Time(s) 0.0154 | Loss 0.8659 | TrainAcc 0.4444 | ValAcc 0.6000 | ETputs(KTEPS) 55.03
# Epoch 00061 | Time(s) 0.0152 | Loss 0.9547 | TrainAcc 0.4889 | ValAcc 0.6444 | ETputs(KTEPS) 55.66
# Epoch 00062 | Time(s) 0.0150 | Loss 0.8653 | TrainAcc 0.5556 | ValAcc 0.5778 | ETputs(KTEPS) 56.27
# Epoch 00063 | Time(s) 0.0149 | Loss 0.7344 | TrainAcc 0.5556 | ValAcc 0.5111 | ETputs(KTEPS) 56.87
# Epoch 00064 | Time(s) 0.0147 | Loss 0.8247 | TrainAcc 0.4667 | ValAcc 0.6444 | ETputs(KTEPS) 57.48
# Epoch 00065 | Time(s) 0.0146 | Loss 0.9659 | TrainAcc 0.3333 | ValAcc 0.5556 | ETputs(KTEPS) 58.08
# Epoch 00066 | Time(s) 0.0144 | Loss 0.7376 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 58.67
# Epoch 00067 | Time(s) 0.0143 | Loss 0.7177 | TrainAcc 0.4889 | ValAcc 0.4222 | ETputs(KTEPS) 59.26
# Epoch 00068 | Time(s) 0.0141 | Loss 0.6750 | TrainAcc 0.6444 | ValAcc 0.3556 | ETputs(KTEPS) 59.85
# Epoch 00069 | Time(s) 0.0140 | Loss 0.8352 | TrainAcc 0.4444 | ValAcc 0.4444 | ETputs(KTEPS) 60.42
# Epoch 00070 | Time(s) 0.0139 | Loss 1.0552 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 60.99
# Epoch 00071 | Time(s) 0.0137 | Loss 0.8414 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 61.54
# Epoch 00072 | Time(s) 0.0136 | Loss 0.7288 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 62.11
# Epoch 00073 | Time(s) 0.0135 | Loss 0.7802 | TrainAcc 0.4667 | ValAcc 0.7111 | ETputs(KTEPS) 62.64
# Epoch 00074 | Time(s) 0.0134 | Loss 0.7329 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 63.19
# Epoch 00075 | Time(s) 0.0133 | Loss 0.9832 | TrainAcc 0.5111 | ValAcc 0.7333 | ETputs(KTEPS) 63.74
# Epoch 00076 | Time(s) 0.0132 | Loss 0.7959 | TrainAcc 0.3556 | ValAcc 0.4667 | ETputs(KTEPS) 64.27
# Epoch 00077 | Time(s) 0.0131 | Loss 0.7164 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 64.81
# Epoch 00078 | Time(s) 0.0129 | Loss 0.7330 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 65.34
# Epoch 00079 | Time(s) 0.0129 | Loss 1.0419 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 65.65
# Epoch 00080 | Time(s) 0.0128 | Loss 0.7359 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 66.16
# Epoch 00081 | Time(s) 0.0127 | Loss 0.7929 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 66.68
# Epoch 00082 | Time(s) 0.0126 | Loss 0.8515 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 67.18
# Epoch 00083 | Time(s) 0.0125 | Loss 0.8898 | TrainAcc 0.4000 | ValAcc 0.5333 | ETputs(KTEPS) 67.70
# Epoch 00084 | Time(s) 0.0124 | Loss 0.7555 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 68.21
# Epoch 00085 | Time(s) 0.0123 | Loss 0.7031 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 68.69
# Epoch 00086 | Time(s) 0.0122 | Loss 0.7411 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 69.17
# Epoch 00087 | Time(s) 0.0121 | Loss 0.7021 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 69.65
# Epoch 00088 | Time(s) 0.0121 | Loss 0.8733 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 70.14
# Epoch 00089 | Time(s) 0.0120 | Loss 0.7931 | TrainAcc 0.5333 | ValAcc 0.5556 | ETputs(KTEPS) 70.62
# Epoch 00090 | Time(s) 0.0119 | Loss 0.6956 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 71.01
# Epoch 00091 | Time(s) 0.0118 | Loss 0.8960 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 71.45
# Epoch 00092 | Time(s) 0.0118 | Loss 0.6902 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 71.92
# Epoch 00093 | Time(s) 0.0117 | Loss 0.7005 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 72.38
# Epoch 00094 | Time(s) 0.0116 | Loss 0.7226 | TrainAcc 0.6000 | ValAcc 0.5333 | ETputs(KTEPS) 72.83
# Epoch 00095 | Time(s) 0.0115 | Loss 0.7472 | TrainAcc 0.3556 | ValAcc 0.5333 | ETputs(KTEPS) 73.29
# Epoch 00096 | Time(s) 0.0115 | Loss 0.7344 | TrainAcc 0.4222 | ValAcc 0.5333 | ETputs(KTEPS) 73.74
# Epoch 00097 | Time(s) 0.0114 | Loss 0.8315 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 74.19
# Epoch 00098 | Time(s) 0.0113 | Loss 0.7536 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 74.63
# Epoch 00099 | Time(s) 0.0113 | Loss 0.7233 | TrainAcc 0.5333 | ValAcc 0.4222 | ETputs(KTEPS) 75.08
# Epoch 00100 | Time(s) 0.0112 | Loss 0.8288 | TrainAcc 0.3556 | ValAcc 0.4222 | ETputs(KTEPS) 75.52
# Epoch 00101 | Time(s) 0.0111 | Loss 0.7696 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 75.95
# Epoch 00102 | Time(s) 0.0111 | Loss 0.7060 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 76.39
# Epoch 00103 | Time(s) 0.0110 | Loss 0.9859 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 76.81
# Epoch 00104 | Time(s) 0.0110 | Loss 0.7090 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 77.23
# Epoch 00105 | Time(s) 0.0109 | Loss 0.9012 | TrainAcc 0.4222 | ValAcc 0.5333 | ETputs(KTEPS) 77.63
# Epoch 00106 | Time(s) 0.0108 | Loss 0.7318 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 78.05
# Epoch 00107 | Time(s) 0.0108 | Loss 0.7512 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 78.46
# Epoch 00108 | Time(s) 0.0107 | Loss 0.9003 | TrainAcc 0.4889 | ValAcc 0.6222 | ETputs(KTEPS) 78.88
# Epoch 00109 | Time(s) 0.0107 | Loss 1.0130 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 79.27
# Epoch 00110 | Time(s) 0.0106 | Loss 0.6971 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 79.67
# Epoch 00111 | Time(s) 0.0106 | Loss 0.7720 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 80.07
# Epoch 00112 | Time(s) 0.0105 | Loss 0.7651 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 80.46
# Epoch 00113 | Time(s) 0.0105 | Loss 0.8240 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 80.84
# Epoch 00114 | Time(s) 0.0104 | Loss 0.7671 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 81.24
# Epoch 00115 | Time(s) 0.0104 | Loss 0.7942 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 81.61
# Epoch 00116 | Time(s) 0.0103 | Loss 0.7550 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 82.01
# Epoch 00117 | Time(s) 0.0103 | Loss 0.7424 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 82.39
# Epoch 00118 | Time(s) 0.0102 | Loss 0.7902 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 82.77
# Epoch 00119 | Time(s) 0.0102 | Loss 0.7625 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 83.15
# Epoch 00120 | Time(s) 0.0101 | Loss 0.7800 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 83.51
# Epoch 00121 | Time(s) 0.0101 | Loss 0.6729 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 83.87
# Epoch 00122 | Time(s) 0.0100 | Loss 0.7962 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 84.24
# Epoch 00123 | Time(s) 0.0100 | Loss 0.7135 | TrainAcc 0.6000 | ValAcc 0.5333 | ETputs(KTEPS) 84.59
# Epoch 00124 | Time(s) 0.0100 | Loss 0.7152 | TrainAcc 0.6000 | ValAcc 0.5333 | ETputs(KTEPS) 84.96
# Epoch 00125 | Time(s) 0.0099 | Loss 0.7193 | TrainAcc 0.6000 | ValAcc 0.5333 | ETputs(KTEPS) 85.32
# Epoch 00126 | Time(s) 0.0099 | Loss 0.7106 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 85.68
# Epoch 00127 | Time(s) 0.0098 | Loss 0.6688 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 86.01
# Epoch 00128 | Time(s) 0.0098 | Loss 0.7721 | TrainAcc 0.4222 | ValAcc 0.5333 | ETputs(KTEPS) 86.36
# Epoch 00129 | Time(s) 0.0098 | Loss 0.6668 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 86.70
# Epoch 00130 | Time(s) 0.0097 | Loss 0.7123 | TrainAcc 0.4000 | ValAcc 0.5333 | ETputs(KTEPS) 87.05
# Epoch 00131 | Time(s) 0.0097 | Loss 0.6953 | TrainAcc 0.6000 | ValAcc 0.5333 | ETputs(KTEPS) 87.38
# Epoch 00132 | Time(s) 0.0096 | Loss 0.7022 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 87.73
# Epoch 00133 | Time(s) 0.0096 | Loss 1.0122 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 88.07
# Epoch 00134 | Time(s) 0.0096 | Loss 0.7022 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 88.41
# Epoch 00135 | Time(s) 0.0095 | Loss 0.7049 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 88.75
# Epoch 00136 | Time(s) 0.0095 | Loss 0.7490 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 89.07
# Epoch 00137 | Time(s) 0.0095 | Loss 0.7549 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 89.38
# Epoch 00138 | Time(s) 0.0094 | Loss 0.7972 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 89.72
# Epoch 00139 | Time(s) 0.0094 | Loss 0.8584 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 90.02
# Epoch 00140 | Time(s) 0.0094 | Loss 0.7111 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 90.33
# Epoch 00141 | Time(s) 0.0093 | Loss 0.7205 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 90.66
# Epoch 00142 | Time(s) 0.0093 | Loss 0.7261 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 90.98
# Epoch 00143 | Time(s) 0.0093 | Loss 0.6298 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 91.29
# Epoch 00144 | Time(s) 0.0092 | Loss 0.7727 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 91.59
# Epoch 00145 | Time(s) 0.0092 | Loss 0.8414 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 91.88
# Epoch 00146 | Time(s) 0.0092 | Loss 0.6654 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 92.17
# Epoch 00147 | Time(s) 0.0091 | Loss 0.6580 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 92.48
# Epoch 00148 | Time(s) 0.0091 | Loss 0.8575 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 92.77
# Epoch 00149 | Time(s) 0.0091 | Loss 0.7284 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 93.08
# Epoch 00150 | Time(s) 0.0091 | Loss 0.8152 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 93.38
# Epoch 00151 | Time(s) 0.0090 | Loss 1.1219 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 93.67
# Epoch 00152 | Time(s) 0.0090 | Loss 0.7811 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 93.95
# Epoch 00153 | Time(s) 0.0090 | Loss 1.5213 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 94.26
# Epoch 00154 | Time(s) 0.0089 | Loss 0.8185 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 94.55
# Epoch 00155 | Time(s) 0.0089 | Loss 0.6764 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 94.83
# Epoch 00156 | Time(s) 0.0089 | Loss 0.6979 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 95.14
# Epoch 00157 | Time(s) 0.0089 | Loss 0.7143 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 95.42
# Epoch 00158 | Time(s) 0.0088 | Loss 0.7888 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 95.69
# Epoch 00159 | Time(s) 0.0088 | Loss 0.7854 | TrainAcc 0.4000 | ValAcc 0.4667 | ETputs(KTEPS) 95.99
# Epoch 00160 | Time(s) 0.0088 | Loss 0.7493 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 96.27
# Epoch 00161 | Time(s) 0.0088 | Loss 0.7466 | TrainAcc 0.4000 | ValAcc 0.6000 | ETputs(KTEPS) 96.55
# Epoch 00162 | Time(s) 0.0087 | Loss 0.6716 | TrainAcc 0.6222 | ValAcc 0.5333 | ETputs(KTEPS) 96.83
# Epoch 00163 | Time(s) 0.0087 | Loss 0.7602 | TrainAcc 0.4000 | ValAcc 0.5333 | ETputs(KTEPS) 97.10
# Epoch 00164 | Time(s) 0.0087 | Loss 0.7024 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 97.38
# Epoch 00165 | Time(s) 0.0087 | Loss 0.6988 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 97.65
# Epoch 00166 | Time(s) 0.0086 | Loss 0.7739 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 97.91
# Epoch 00167 | Time(s) 0.0086 | Loss 0.7394 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 98.17
# Epoch 00168 | Time(s) 0.0086 | Loss 0.7985 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 98.43
# Epoch 00169 | Time(s) 0.0086 | Loss 0.8283 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 98.68
# Epoch 00170 | Time(s) 0.0085 | Loss 0.6777 | TrainAcc 0.5333 | ValAcc 0.6667 | ETputs(KTEPS) 98.95
# Epoch 00171 | Time(s) 0.0085 | Loss 0.7024 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 99.22
# Epoch 00172 | Time(s) 0.0085 | Loss 0.8663 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 99.49
# Epoch 00173 | Time(s) 0.0085 | Loss 0.6945 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 99.74
# Epoch 00174 | Time(s) 0.0085 | Loss 0.7198 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 99.99
# Epoch 00175 | Time(s) 0.0084 | Loss 0.7298 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 100.24
# Epoch 00176 | Time(s) 0.0084 | Loss 0.6531 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 100.48
# Epoch 00177 | Time(s) 0.0084 | Loss 0.7002 | TrainAcc 0.5556 | ValAcc 0.4000 | ETputs(KTEPS) 100.73
# Epoch 00178 | Time(s) 0.0084 | Loss 0.7149 | TrainAcc 0.5556 | ValAcc 0.3333 | ETputs(KTEPS) 100.98
# Epoch 00179 | Time(s) 0.0084 | Loss 0.7937 | TrainAcc 0.5556 | ValAcc 0.4222 | ETputs(KTEPS) 101.22
# Epoch 00180 | Time(s) 0.0083 | Loss 0.7283 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 101.47
# Epoch 00181 | Time(s) 0.0083 | Loss 0.7584 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 101.69
# Epoch 00182 | Time(s) 0.0083 | Loss 0.6725 | TrainAcc 0.6222 | ValAcc 0.4667 | ETputs(KTEPS) 101.93
# Epoch 00183 | Time(s) 0.0083 | Loss 0.7541 | TrainAcc 0.5333 | ValAcc 0.3778 | ETputs(KTEPS) 102.18
# Epoch 00184 | Time(s) 0.0083 | Loss 0.7125 | TrainAcc 0.4667 | ValAcc 0.3333 | ETputs(KTEPS) 102.41
# Epoch 00185 | Time(s) 0.0082 | Loss 0.6559 | TrainAcc 0.4667 | ValAcc 0.4222 | ETputs(KTEPS) 102.65
# Epoch 00186 | Time(s) 0.0082 | Loss 0.7538 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 102.87
# Epoch 00187 | Time(s) 0.0082 | Loss 0.6815 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 103.11
# Epoch 00188 | Time(s) 0.0082 | Loss 0.6743 | TrainAcc 0.6000 | ValAcc 0.4667 | ETputs(KTEPS) 103.34
# Epoch 00189 | Time(s) 0.0082 | Loss 0.7023 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 103.56
# Epoch 00190 | Time(s) 0.0082 | Loss 0.7071 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 103.80
# Epoch 00191 | Time(s) 0.0081 | Loss 0.7026 | TrainAcc 0.4000 | ValAcc 0.4667 | ETputs(KTEPS) 104.04
# Epoch 00192 | Time(s) 0.0081 | Loss 0.6815 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 104.27
# Epoch 00193 | Time(s) 0.0081 | Loss 0.7594 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 104.49
# Epoch 00194 | Time(s) 0.0081 | Loss 0.7062 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 104.71
# Epoch 00195 | Time(s) 0.0081 | Loss 0.7519 | TrainAcc 0.5333 | ValAcc 0.5111 | ETputs(KTEPS) 104.94
# Epoch 00196 | Time(s) 0.0080 | Loss 0.6795 | TrainAcc 0.6667 | ValAcc 0.6667 | ETputs(KTEPS) 105.16
# Epoch 00197 | Time(s) 0.0080 | Loss 0.6904 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 105.37
# Epoch 00198 | Time(s) 0.0080 | Loss 0.6604 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 105.59
# Epoch 00199 | Time(s) 0.0080 | Loss 0.7990 | TrainAcc 0.4222 | ValAcc 0.5111 | ETputs(KTEPS) 105.79
# Epoch 00200 | Time(s) 0.0080 | Loss 0.6796 | TrainAcc 0.5556 | ValAcc 0.6000 | ETputs(KTEPS) 106.00
# Epoch 00201 | Time(s) 0.0080 | Loss 0.6709 | TrainAcc 0.6222 | ValAcc 0.5333 | ETputs(KTEPS) 106.21
# Epoch 00202 | Time(s) 0.0079 | Loss 0.6543 | TrainAcc 0.6222 | ValAcc 0.5333 | ETputs(KTEPS) 106.42
# Epoch 00203 | Time(s) 0.0079 | Loss 0.6661 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 106.64
# Epoch 00204 | Time(s) 0.0079 | Loss 0.6746 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 106.87
# Epoch 00205 | Time(s) 0.0079 | Loss 0.7489 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 107.08
# Epoch 00206 | Time(s) 0.0079 | Loss 0.7417 | TrainAcc 0.5111 | ValAcc 0.6667 | ETputs(KTEPS) 107.28
# Epoch 00207 | Time(s) 0.0079 | Loss 0.7393 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 107.50
# Epoch 00208 | Time(s) 0.0079 | Loss 0.7294 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 107.71
# Epoch 00209 | Time(s) 0.0078 | Loss 0.8286 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 107.92
# Epoch 00210 | Time(s) 0.0078 | Loss 0.6852 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 108.11
# Epoch 00211 | Time(s) 0.0078 | Loss 0.6809 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 108.31
# Epoch 00212 | Time(s) 0.0078 | Loss 0.7160 | TrainAcc 0.4000 | ValAcc 0.4667 | ETputs(KTEPS) 108.52
# Epoch 00213 | Time(s) 0.0078 | Loss 0.6765 | TrainAcc 0.5778 | ValAcc 0.4444 | ETputs(KTEPS) 108.72
# Epoch 00214 | Time(s) 0.0078 | Loss 0.7341 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 108.93
# Epoch 00215 | Time(s) 0.0078 | Loss 0.7025 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 109.13
# Epoch 00216 | Time(s) 0.0077 | Loss 0.7132 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 109.34
# Epoch 00217 | Time(s) 0.0077 | Loss 0.6847 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 109.52
# Epoch 00218 | Time(s) 0.0077 | Loss 0.7355 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 109.70
# Epoch 00219 | Time(s) 0.0077 | Loss 0.6991 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 109.89
# Epoch 00220 | Time(s) 0.0077 | Loss 0.7261 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 110.09
# Epoch 00221 | Time(s) 0.0077 | Loss 0.6901 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 110.27
# Epoch 00222 | Time(s) 0.0077 | Loss 0.7110 | TrainAcc 0.4000 | ValAcc 0.4667 | ETputs(KTEPS) 110.36
# Epoch 00223 | Time(s) 0.0077 | Loss 0.7393 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 110.54
# Epoch 00224 | Time(s) 0.0076 | Loss 0.6987 | TrainAcc 0.4889 | ValAcc 0.4444 | ETputs(KTEPS) 110.73
# Epoch 00225 | Time(s) 0.0076 | Loss 0.7629 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 110.91
# Epoch 00226 | Time(s) 0.0076 | Loss 0.7136 | TrainAcc 0.6222 | ValAcc 0.4667 | ETputs(KTEPS) 111.10
# Epoch 00227 | Time(s) 0.0076 | Loss 0.6974 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 111.28
# Epoch 00228 | Time(s) 0.0076 | Loss 0.9569 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 111.46
# Epoch 00229 | Time(s) 0.0076 | Loss 0.7850 | TrainAcc 0.6000 | ValAcc 0.4667 | ETputs(KTEPS) 111.63
# Epoch 00230 | Time(s) 0.0076 | Loss 0.7128 | TrainAcc 0.5778 | ValAcc 0.6222 | ETputs(KTEPS) 111.82
# Epoch 00231 | Time(s) 0.0076 | Loss 0.6937 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 112.00
# Epoch 00232 | Time(s) 0.0075 | Loss 0.6703 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 112.17
# Epoch 00233 | Time(s) 0.0075 | Loss 0.7544 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 112.35
# Epoch 00234 | Time(s) 0.0075 | Loss 0.7460 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 112.50
# Epoch 00235 | Time(s) 0.0075 | Loss 0.6556 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 112.67
# Epoch 00236 | Time(s) 0.0075 | Loss 0.6921 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 112.84
# Epoch 00237 | Time(s) 0.0075 | Loss 0.7177 | TrainAcc 0.4667 | ValAcc 0.3556 | ETputs(KTEPS) 113.02
# Epoch 00238 | Time(s) 0.0075 | Loss 0.7549 | TrainAcc 0.4000 | ValAcc 0.4667 | ETputs(KTEPS) 113.20
# Epoch 00239 | Time(s) 0.0075 | Loss 0.6579 | TrainAcc 0.6222 | ValAcc 0.4667 | ETputs(KTEPS) 113.37
# Epoch 00240 | Time(s) 0.0075 | Loss 0.6911 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 113.54
# Epoch 00241 | Time(s) 0.0074 | Loss 0.7050 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 113.70
# Epoch 00242 | Time(s) 0.0074 | Loss 0.7357 | TrainAcc 0.3778 | ValAcc 0.4667 | ETputs(KTEPS) 113.87
# Epoch 00243 | Time(s) 0.0074 | Loss 0.7548 | TrainAcc 0.3778 | ValAcc 0.4667 | ETputs(KTEPS) 114.04
# Epoch 00244 | Time(s) 0.0074 | Loss 0.6941 | TrainAcc 0.5111 | ValAcc 0.3778 | ETputs(KTEPS) 114.22
# Epoch 00245 | Time(s) 0.0074 | Loss 0.7556 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 114.39
# Epoch 00246 | Time(s) 0.0074 | Loss 0.7879 | TrainAcc 0.5111 | ValAcc 0.4444 | ETputs(KTEPS) 114.54
# Epoch 00247 | Time(s) 0.0074 | Loss 0.7433 | TrainAcc 0.5556 | ValAcc 0.4000 | ETputs(KTEPS) 114.72
# Epoch 00248 | Time(s) 0.0074 | Loss 0.6557 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 114.88
# Epoch 00249 | Time(s) 0.0074 | Loss 0.6769 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 115.06
# Epoch 00250 | Time(s) 0.0073 | Loss 0.7280 | TrainAcc 0.6222 | ValAcc 0.4667 | ETputs(KTEPS) 115.24
# Epoch 00251 | Time(s) 0.0073 | Loss 0.7076 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 115.41
# Epoch 00252 | Time(s) 0.0073 | Loss 0.7097 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 115.57
# Epoch 00253 | Time(s) 0.0073 | Loss 0.7790 | TrainAcc 0.3778 | ValAcc 0.4667 | ETputs(KTEPS) 115.72
# Epoch 00254 | Time(s) 0.0073 | Loss 0.7834 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 115.88
# Epoch 00255 | Time(s) 0.0073 | Loss 0.7456 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 116.04
# Epoch 00256 | Time(s) 0.0073 | Loss 0.6379 | TrainAcc 0.6222 | ValAcc 0.4667 | ETputs(KTEPS) 116.19
# Epoch 00257 | Time(s) 0.0073 | Loss 0.7154 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 116.35
# Epoch 00258 | Time(s) 0.0073 | Loss 0.6799 | TrainAcc 0.6444 | ValAcc 0.5333 | ETputs(KTEPS) 116.52
# Epoch 00259 | Time(s) 0.0073 | Loss 0.6804 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 116.68
# Epoch 00260 | Time(s) 0.0072 | Loss 0.7496 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 116.84
# Epoch 00261 | Time(s) 0.0072 | Loss 0.7013 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 116.99
# Epoch 00262 | Time(s) 0.0072 | Loss 0.6913 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 117.13
# Epoch 00263 | Time(s) 0.0072 | Loss 0.7289 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 117.30
# Epoch 00264 | Time(s) 0.0072 | Loss 0.6982 | TrainAcc 0.4000 | ValAcc 0.5333 | ETputs(KTEPS) 117.45
# Epoch 00265 | Time(s) 0.0072 | Loss 0.7171 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 117.61
# Epoch 00266 | Time(s) 0.0072 | Loss 0.6990 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 117.77
# Epoch 00267 | Time(s) 0.0072 | Loss 0.7471 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 117.92
# Epoch 00268 | Time(s) 0.0072 | Loss 0.8056 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 118.08
# Epoch 00269 | Time(s) 0.0072 | Loss 0.6727 | TrainAcc 0.4667 | ValAcc 0.6000 | ETputs(KTEPS) 118.22
# Epoch 00270 | Time(s) 0.0071 | Loss 0.8127 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 118.36
# Epoch 00271 | Time(s) 0.0071 | Loss 0.7944 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 118.50
# Epoch 00272 | Time(s) 0.0071 | Loss 0.8879 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 118.64
# Epoch 00273 | Time(s) 0.0071 | Loss 0.7109 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 118.80
# Epoch 00274 | Time(s) 0.0071 | Loss 0.7260 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 118.95
# Epoch 00275 | Time(s) 0.0071 | Loss 0.7198 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 119.10
# Epoch 00276 | Time(s) 0.0071 | Loss 0.7387 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 119.24
# Epoch 00277 | Time(s) 0.0071 | Loss 0.6775 | TrainAcc 0.5111 | ValAcc 0.4000 | ETputs(KTEPS) 119.38
# Epoch 00278 | Time(s) 0.0071 | Loss 0.7064 | TrainAcc 0.5556 | ValAcc 0.3111 | ETputs(KTEPS) 119.54
# Epoch 00279 | Time(s) 0.0071 | Loss 0.6962 | TrainAcc 0.4667 | ValAcc 0.4889 | ETputs(KTEPS) 119.68
# Epoch 00280 | Time(s) 0.0071 | Loss 0.7118 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 119.82
# Epoch 00281 | Time(s) 0.0071 | Loss 0.7218 | TrainAcc 0.4667 | ValAcc 0.3556 | ETputs(KTEPS) 119.95
# Epoch 00282 | Time(s) 0.0070 | Loss 0.6583 | TrainAcc 0.5778 | ValAcc 0.3111 | ETputs(KTEPS) 120.09
# Epoch 00283 | Time(s) 0.0070 | Loss 0.7342 | TrainAcc 0.4222 | ValAcc 0.3111 | ETputs(KTEPS) 120.22
# Epoch 00284 | Time(s) 0.0070 | Loss 0.6726 | TrainAcc 0.6667 | ValAcc 0.4000 | ETputs(KTEPS) 120.37
# Epoch 00285 | Time(s) 0.0070 | Loss 0.6378 | TrainAcc 0.6000 | ValAcc 0.3778 | ETputs(KTEPS) 120.51
# Epoch 00286 | Time(s) 0.0070 | Loss 0.6795 | TrainAcc 0.5556 | ValAcc 0.4000 | ETputs(KTEPS) 120.66
# Epoch 00287 | Time(s) 0.0070 | Loss 0.6768 | TrainAcc 0.6000 | ValAcc 0.4667 | ETputs(KTEPS) 120.80
# Epoch 00288 | Time(s) 0.0070 | Loss 0.7144 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 120.93
# Epoch 00289 | Time(s) 0.0070 | Loss 0.7229 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 121.06
# Epoch 00290 | Time(s) 0.0070 | Loss 0.7234 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 121.20
# Epoch 00291 | Time(s) 0.0070 | Loss 0.7401 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 121.32
# Epoch 00292 | Time(s) 0.0070 | Loss 0.6943 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 121.45
# Epoch 00293 | Time(s) 0.0070 | Loss 0.7104 | TrainAcc 0.3556 | ValAcc 0.4667 | ETputs(KTEPS) 121.59
# Epoch 00294 | Time(s) 0.0070 | Loss 0.7266 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 121.71
# Epoch 00295 | Time(s) 0.0069 | Loss 0.6959 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 121.86
# Epoch 00296 | Time(s) 0.0069 | Loss 0.8721 | TrainAcc 0.5111 | ValAcc 0.3778 | ETputs(KTEPS) 121.99
# Epoch 00297 | Time(s) 0.0069 | Loss 0.7656 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 122.12
# Epoch 00298 | Time(s) 0.0069 | Loss 0.6680 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 122.25
# Epoch 00299 | Time(s) 0.0069 | Loss 0.7163 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 122.38
# Epoch 00300 | Time(s) 0.0069 | Loss 0.6610 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 122.52
# Epoch 00301 | Time(s) 0.0069 | Loss 0.7192 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 122.65
# Epoch 00302 | Time(s) 0.0069 | Loss 0.7393 | TrainAcc 0.5333 | ValAcc 0.3333 | ETputs(KTEPS) 122.77
# Epoch 00303 | Time(s) 0.0069 | Loss 0.6826 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 122.91
# Epoch 00304 | Time(s) 0.0069 | Loss 0.6814 | TrainAcc 0.6000 | ValAcc 0.4667 | ETputs(KTEPS) 123.04
# Epoch 00305 | Time(s) 0.0069 | Loss 0.6679 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 123.17
# Epoch 00306 | Time(s) 0.0069 | Loss 0.6777 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 123.30
# Epoch 00307 | Time(s) 0.0069 | Loss 0.6273 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 123.40
# Epoch 00308 | Time(s) 0.0068 | Loss 0.8175 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 123.53
# Epoch 00309 | Time(s) 0.0068 | Loss 0.7398 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 123.65
# Epoch 00310 | Time(s) 0.0068 | Loss 0.7067 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 123.77
# Epoch 00311 | Time(s) 0.0068 | Loss 0.7304 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 123.90
# Epoch 00312 | Time(s) 0.0068 | Loss 0.6789 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 124.02
# Epoch 00313 | Time(s) 0.0068 | Loss 0.6736 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 124.14
# Epoch 00314 | Time(s) 0.0068 | Loss 0.8494 | TrainAcc 0.4222 | ValAcc 0.5333 | ETputs(KTEPS) 124.28
# Epoch 00315 | Time(s) 0.0068 | Loss 0.6911 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 124.41
# Epoch 00316 | Time(s) 0.0068 | Loss 0.7416 | TrainAcc 0.4889 | ValAcc 0.4444 | ETputs(KTEPS) 124.53
# Epoch 00317 | Time(s) 0.0068 | Loss 0.7203 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 124.65
# Epoch 00318 | Time(s) 0.0068 | Loss 0.6714 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 124.76
# Epoch 00319 | Time(s) 0.0068 | Loss 0.6832 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 124.88
# Epoch 00320 | Time(s) 0.0068 | Loss 0.6615 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 125.00
# Epoch 00321 | Time(s) 0.0068 | Loss 0.7256 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 125.11
# Epoch 00322 | Time(s) 0.0068 | Loss 0.7636 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 125.21
# Epoch 00323 | Time(s) 0.0068 | Loss 0.7508 | TrainAcc 0.3778 | ValAcc 0.4667 | ETputs(KTEPS) 125.33
# Epoch 00324 | Time(s) 0.0067 | Loss 0.6975 | TrainAcc 0.3778 | ValAcc 0.4667 | ETputs(KTEPS) 125.45
# Epoch 00325 | Time(s) 0.0067 | Loss 0.7982 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 125.55
# Epoch 00326 | Time(s) 0.0067 | Loss 0.8479 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 125.66
# Epoch 00327 | Time(s) 0.0067 | Loss 0.6992 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 125.78
# Epoch 00328 | Time(s) 0.0067 | Loss 0.6931 | TrainAcc 0.3556 | ValAcc 0.6000 | ETputs(KTEPS) 125.90
# Epoch 00329 | Time(s) 0.0067 | Loss 0.6668 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 126.00
# Epoch 00330 | Time(s) 0.0067 | Loss 0.7062 | TrainAcc 0.4000 | ValAcc 0.5333 | ETputs(KTEPS) 126.11
# Epoch 00331 | Time(s) 0.0067 | Loss 0.7186 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 126.23
# Epoch 00332 | Time(s) 0.0067 | Loss 0.7747 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 126.33
# Epoch 00333 | Time(s) 0.0067 | Loss 0.7395 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 126.43
# Epoch 00334 | Time(s) 0.0067 | Loss 0.7538 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 126.55
# Epoch 00335 | Time(s) 0.0067 | Loss 0.7827 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 126.66
# Epoch 00336 | Time(s) 0.0067 | Loss 0.8259 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 126.77
# Epoch 00337 | Time(s) 0.0067 | Loss 0.6901 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 126.87
# Epoch 00338 | Time(s) 0.0067 | Loss 0.7781 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 126.97
# Epoch 00339 | Time(s) 0.0067 | Loss 0.6982 | TrainAcc 0.6444 | ValAcc 0.4667 | ETputs(KTEPS) 127.08
# Epoch 00340 | Time(s) 0.0067 | Loss 0.9585 | TrainAcc 0.6222 | ValAcc 0.5333 | ETputs(KTEPS) 127.19
# Epoch 00341 | Time(s) 0.0066 | Loss 0.6828 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 127.29
# Epoch 00342 | Time(s) 0.0066 | Loss 0.6816 | TrainAcc 0.6000 | ValAcc 0.5333 | ETputs(KTEPS) 127.40
# Epoch 00343 | Time(s) 0.0066 | Loss 0.7095 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 127.50
# Epoch 00344 | Time(s) 0.0066 | Loss 0.7746 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 127.60
# Epoch 00345 | Time(s) 0.0066 | Loss 1.0767 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 127.71
# Epoch 00346 | Time(s) 0.0066 | Loss 0.6931 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 127.80
# Epoch 00347 | Time(s) 0.0066 | Loss 0.6649 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 127.92
# Epoch 00348 | Time(s) 0.0066 | Loss 0.6569 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 128.01
# Epoch 00349 | Time(s) 0.0066 | Loss 0.6910 | TrainAcc 0.5111 | ValAcc 0.3111 | ETputs(KTEPS) 128.13
# Epoch 00350 | Time(s) 0.0066 | Loss 0.7638 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 128.24
# Epoch 00351 | Time(s) 0.0066 | Loss 0.6813 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 128.35
# Epoch 00352 | Time(s) 0.0066 | Loss 0.6910 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 128.45
# Epoch 00353 | Time(s) 0.0066 | Loss 0.8790 | TrainAcc 0.3111 | ValAcc 0.4667 | ETputs(KTEPS) 128.56
# Epoch 00354 | Time(s) 0.0066 | Loss 0.6962 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 128.66
# Epoch 00355 | Time(s) 0.0066 | Loss 0.6991 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 128.77
# Epoch 00356 | Time(s) 0.0066 | Loss 0.7510 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 128.87
# Epoch 00357 | Time(s) 0.0066 | Loss 0.6864 | TrainAcc 0.4000 | ValAcc 0.4000 | ETputs(KTEPS) 128.96
# Epoch 00358 | Time(s) 0.0066 | Loss 0.6975 | TrainAcc 0.5333 | ValAcc 0.4000 | ETputs(KTEPS) 129.06
# Epoch 00359 | Time(s) 0.0065 | Loss 0.7430 | TrainAcc 0.4667 | ValAcc 0.3333 | ETputs(KTEPS) 129.17
# Epoch 00360 | Time(s) 0.0065 | Loss 0.8467 | TrainAcc 0.5111 | ValAcc 0.4222 | ETputs(KTEPS) 129.27
# Epoch 00361 | Time(s) 0.0065 | Loss 0.6780 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 129.37
# Epoch 00362 | Time(s) 0.0065 | Loss 0.6984 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 129.45
# Epoch 00363 | Time(s) 0.0065 | Loss 0.6919 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 129.54
# Epoch 00364 | Time(s) 0.0065 | Loss 1.2231 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 129.64
# Epoch 00365 | Time(s) 0.0065 | Loss 0.6889 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 129.75
# Epoch 00366 | Time(s) 0.0065 | Loss 0.7921 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 129.84
# Epoch 00367 | Time(s) 0.0065 | Loss 0.7317 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 129.93
# Epoch 00368 | Time(s) 0.0065 | Loss 0.6949 | TrainAcc 0.4222 | ValAcc 0.3778 | ETputs(KTEPS) 130.02
# Epoch 00369 | Time(s) 0.0065 | Loss 0.6862 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 130.12
# Epoch 00370 | Time(s) 0.0065 | Loss 0.7256 | TrainAcc 0.4000 | ValAcc 0.4667 | ETputs(KTEPS) 130.23
# Epoch 00371 | Time(s) 0.0065 | Loss 0.7057 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 130.33
# Epoch 00372 | Time(s) 0.0065 | Loss 0.7086 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 130.43
# Epoch 00373 | Time(s) 0.0065 | Loss 0.7813 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 130.53
# Epoch 00374 | Time(s) 0.0065 | Loss 0.6854 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 130.63
# Epoch 00375 | Time(s) 0.0065 | Loss 0.6947 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 130.72
# Epoch 00376 | Time(s) 0.0065 | Loss 0.6939 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 130.81
# Epoch 00377 | Time(s) 0.0065 | Loss 0.6810 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 130.90
# Epoch 00378 | Time(s) 0.0065 | Loss 0.7004 | TrainAcc 0.4444 | ValAcc 0.3111 | ETputs(KTEPS) 130.96
# Epoch 00379 | Time(s) 0.0065 | Loss 0.6815 | TrainAcc 0.6000 | ValAcc 0.4667 | ETputs(KTEPS) 131.04
# Epoch 00380 | Time(s) 0.0065 | Loss 0.7763 | TrainAcc 0.4222 | ValAcc 0.5333 | ETputs(KTEPS) 131.14
# Epoch 00381 | Time(s) 0.0064 | Loss 0.7833 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 131.24
# Epoch 00382 | Time(s) 0.0064 | Loss 0.7086 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 131.32
# Epoch 00383 | Time(s) 0.0064 | Loss 0.8128 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 131.41
# Epoch 00384 | Time(s) 0.0064 | Loss 0.7042 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 131.49
# Epoch 00385 | Time(s) 0.0064 | Loss 0.7070 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 131.59
# Epoch 00386 | Time(s) 0.0064 | Loss 1.4163 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 131.68
# Epoch 00387 | Time(s) 0.0064 | Loss 1.2857 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 131.78
# Epoch 00388 | Time(s) 0.0064 | Loss 1.5091 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 131.87
# Epoch 00389 | Time(s) 0.0064 | Loss 0.6682 | TrainAcc 0.6000 | ValAcc 0.3778 | ETputs(KTEPS) 131.97
# Epoch 00390 | Time(s) 0.0064 | Loss 0.8286 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 132.06
# Epoch 00391 | Time(s) 0.0064 | Loss 0.7054 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 132.14
# Epoch 00392 | Time(s) 0.0064 | Loss 0.7720 | TrainAcc 0.3778 | ValAcc 0.5333 | ETputs(KTEPS) 132.22
# Epoch 00393 | Time(s) 0.0064 | Loss 0.9539 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 132.32
# Epoch 00394 | Time(s) 0.0064 | Loss 1.4302 | TrainAcc 0.5333 | ValAcc 0.4000 | ETputs(KTEPS) 132.41
# Epoch 00395 | Time(s) 0.0064 | Loss 1.5995 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 132.50
# Epoch 00396 | Time(s) 0.0064 | Loss 0.7196 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 132.58
# Epoch 00397 | Time(s) 0.0064 | Loss 0.6682 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 132.66
# Epoch 00398 | Time(s) 0.0064 | Loss 1.2404 | TrainAcc 0.4444 | ValAcc 0.5778 | ETputs(KTEPS) 132.75
# Epoch 00399 | Time(s) 0.0064 | Loss 0.6787 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 132.83
# Epoch 00400 | Time(s) 0.0064 | Loss 0.8124 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 132.91
# Epoch 00401 | Time(s) 0.0064 | Loss 0.8206 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 133.01
# Epoch 00402 | Time(s) 0.0064 | Loss 0.6908 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 133.09
# Epoch 00403 | Time(s) 0.0064 | Loss 0.6835 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 133.17
# Epoch 00404 | Time(s) 0.0063 | Loss 0.8917 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 133.25
# Epoch 00405 | Time(s) 0.0063 | Loss 0.9146 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 133.34
# Epoch 00406 | Time(s) 0.0063 | Loss 0.7659 | TrainAcc 0.4889 | ValAcc 0.4444 | ETputs(KTEPS) 133.43
# Epoch 00407 | Time(s) 0.0063 | Loss 1.2330 | TrainAcc 0.6222 | ValAcc 0.5333 | ETputs(KTEPS) 133.51
# Epoch 00408 | Time(s) 0.0063 | Loss 0.7098 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 133.59
# Epoch 00409 | Time(s) 0.0063 | Loss 0.9342 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 133.68
# Epoch 00410 | Time(s) 0.0063 | Loss 0.7266 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 133.76
# Epoch 00411 | Time(s) 0.0063 | Loss 1.3465 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 133.85
# Epoch 00412 | Time(s) 0.0063 | Loss 0.7278 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 133.94
# Epoch 00413 | Time(s) 0.0063 | Loss 0.7861 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 134.03
# Epoch 00414 | Time(s) 0.0063 | Loss 0.7674 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 134.11
# Epoch 00415 | Time(s) 0.0063 | Loss 1.0647 | TrainAcc 0.4667 | ValAcc 0.4889 | ETputs(KTEPS) 134.18
# Epoch 00416 | Time(s) 0.0063 | Loss 0.7117 | TrainAcc 0.5556 | ValAcc 0.3556 | ETputs(KTEPS) 134.27
# Epoch 00417 | Time(s) 0.0063 | Loss 2.1478 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 134.35
# Epoch 00418 | Time(s) 0.0063 | Loss 0.8670 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 134.43
# Epoch 00419 | Time(s) 0.0063 | Loss 1.3543 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 134.51
# Epoch 00420 | Time(s) 0.0063 | Loss 0.9521 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 134.59
# Epoch 00421 | Time(s) 0.0063 | Loss 1.5887 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 134.66
# Epoch 00422 | Time(s) 0.0063 | Loss 1.1028 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 134.74
# Epoch 00423 | Time(s) 0.0063 | Loss 2.7902 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 134.82
# Epoch 00424 | Time(s) 0.0063 | Loss 1.0679 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 134.90
# Epoch 00425 | Time(s) 0.0063 | Loss 0.6949 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 134.98
# Epoch 00426 | Time(s) 0.0063 | Loss 0.9546 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 135.06
# Epoch 00427 | Time(s) 0.0063 | Loss 0.8138 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 135.15
# Epoch 00428 | Time(s) 0.0063 | Loss 0.7228 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 135.23
# Epoch 00429 | Time(s) 0.0063 | Loss 0.7125 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 135.30
# Epoch 00430 | Time(s) 0.0062 | Loss 1.3741 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 135.37
# Epoch 00431 | Time(s) 0.0062 | Loss 0.7226 | TrainAcc 0.5333 | ValAcc 0.5111 | ETputs(KTEPS) 135.46
# Epoch 00432 | Time(s) 0.0062 | Loss 0.9066 | TrainAcc 0.5778 | ValAcc 0.3333 | ETputs(KTEPS) 135.54
# Epoch 00433 | Time(s) 0.0062 | Loss 0.7342 | TrainAcc 0.5778 | ValAcc 0.3778 | ETputs(KTEPS) 135.60
# Epoch 00434 | Time(s) 0.0062 | Loss 0.8478 | TrainAcc 0.4222 | ValAcc 0.4000 | ETputs(KTEPS) 135.68
# Epoch 00435 | Time(s) 0.0062 | Loss 0.7779 | TrainAcc 0.4889 | ValAcc 0.4000 | ETputs(KTEPS) 135.76
# Epoch 00436 | Time(s) 0.0062 | Loss 0.9739 | TrainAcc 0.6222 | ValAcc 0.4222 | ETputs(KTEPS) 135.84
# Epoch 00437 | Time(s) 0.0062 | Loss 1.7501 | TrainAcc 0.6000 | ValAcc 0.4667 | ETputs(KTEPS) 135.91
# Epoch 00438 | Time(s) 0.0062 | Loss 1.0734 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 135.98
# Epoch 00439 | Time(s) 0.0062 | Loss 0.6978 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 136.06
# Epoch 00440 | Time(s) 0.0062 | Loss 0.8628 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 136.13
# Epoch 00441 | Time(s) 0.0062 | Loss 0.7237 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 136.20
# Epoch 00442 | Time(s) 0.0062 | Loss 0.6957 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 136.28
# Epoch 00443 | Time(s) 0.0062 | Loss 0.7848 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 136.36
# Epoch 00444 | Time(s) 0.0062 | Loss 0.7237 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 136.43
# Epoch 00445 | Time(s) 0.0062 | Loss 0.7929 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 136.51
# Epoch 00446 | Time(s) 0.0062 | Loss 0.7298 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 136.57
# Epoch 00447 | Time(s) 0.0062 | Loss 0.7481 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 136.65
# Epoch 00448 | Time(s) 0.0062 | Loss 0.8771 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 136.72
# Epoch 00449 | Time(s) 0.0062 | Loss 0.7406 | TrainAcc 0.6222 | ValAcc 0.4667 | ETputs(KTEPS) 136.80
# Epoch 00450 | Time(s) 0.0062 | Loss 0.8238 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 136.88
# Epoch 00451 | Time(s) 0.0062 | Loss 0.7683 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 136.93
# Epoch 00452 | Time(s) 0.0062 | Loss 0.7171 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 137.00
# Epoch 00453 | Time(s) 0.0062 | Loss 0.6678 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 137.07
# Epoch 00454 | Time(s) 0.0062 | Loss 0.6993 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 137.13
# Epoch 00455 | Time(s) 0.0062 | Loss 0.7247 | TrainAcc 0.6444 | ValAcc 0.4667 | ETputs(KTEPS) 137.21
# Epoch 00456 | Time(s) 0.0062 | Loss 0.6929 | TrainAcc 0.5111 | ValAcc 0.3556 | ETputs(KTEPS) 137.27
# Epoch 00457 | Time(s) 0.0062 | Loss 0.6965 | TrainAcc 0.5333 | ValAcc 0.3778 | ETputs(KTEPS) 137.35
# Epoch 00458 | Time(s) 0.0062 | Loss 0.8825 | TrainAcc 0.4444 | ValAcc 0.3778 | ETputs(KTEPS) 137.42
# Epoch 00459 | Time(s) 0.0062 | Loss 0.8105 | TrainAcc 0.4222 | ValAcc 0.3556 | ETputs(KTEPS) 137.49
# Epoch 00460 | Time(s) 0.0061 | Loss 0.6873 | TrainAcc 0.6000 | ValAcc 0.3333 | ETputs(KTEPS) 137.56
# Epoch 00461 | Time(s) 0.0061 | Loss 0.7339 | TrainAcc 0.5111 | ValAcc 0.4889 | ETputs(KTEPS) 137.63
# Epoch 00462 | Time(s) 0.0061 | Loss 3.7373 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 137.69
# Epoch 00463 | Time(s) 0.0061 | Loss 0.7508 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 137.77
# Epoch 00464 | Time(s) 0.0061 | Loss 0.6948 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 137.83
# Epoch 00465 | Time(s) 0.0061 | Loss 1.0139 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 137.89
# Epoch 00466 | Time(s) 0.0061 | Loss 0.8967 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 137.96
# Epoch 00467 | Time(s) 0.0061 | Loss 1.4195 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 138.03
# Epoch 00468 | Time(s) 0.0061 | Loss 0.7623 | TrainAcc 0.5111 | ValAcc 0.6222 | ETputs(KTEPS) 138.11
# Epoch 00469 | Time(s) 0.0061 | Loss 0.8788 | TrainAcc 0.3778 | ValAcc 0.6000 | ETputs(KTEPS) 138.17
# Epoch 00470 | Time(s) 0.0061 | Loss 1.3254 | TrainAcc 0.4667 | ValAcc 0.5556 | ETputs(KTEPS) 138.25
# Epoch 00471 | Time(s) 0.0061 | Loss 0.7366 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 138.32
# Epoch 00472 | Time(s) 0.0061 | Loss 0.8468 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 138.38
# Epoch 00473 | Time(s) 0.0061 | Loss 0.8673 | TrainAcc 0.4000 | ValAcc 0.4667 | ETputs(KTEPS) 138.44
# Epoch 00474 | Time(s) 0.0061 | Loss 0.7098 | TrainAcc 0.4000 | ValAcc 0.4667 | ETputs(KTEPS) 138.51
# Epoch 00475 | Time(s) 0.0061 | Loss 0.6943 | TrainAcc 0.4889 | ValAcc 0.3778 | ETputs(KTEPS) 138.58
# Epoch 00476 | Time(s) 0.0061 | Loss 0.6734 | TrainAcc 0.5111 | ValAcc 0.4000 | ETputs(KTEPS) 138.64
# Epoch 00477 | Time(s) 0.0061 | Loss 0.6880 | TrainAcc 0.4889 | ValAcc 0.3556 | ETputs(KTEPS) 138.71
# Epoch 00478 | Time(s) 0.0061 | Loss 0.8149 | TrainAcc 0.5111 | ValAcc 0.4222 | ETputs(KTEPS) 138.78
# Epoch 00479 | Time(s) 0.0061 | Loss 0.6779 | TrainAcc 0.6444 | ValAcc 0.4667 | ETputs(KTEPS) 138.85
# Epoch 00480 | Time(s) 0.0061 | Loss 0.7546 | TrainAcc 0.6000 | ValAcc 0.4667 | ETputs(KTEPS) 138.91
# ...
# Epoch 01341 | Time(s) 0.0052 | Loss 0.9709 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 163.12
# Epoch 01342 | Time(s) 0.0052 | Loss 2.7915 | TrainAcc 0.6000 | ValAcc 0.4667 | ETputs(KTEPS) 163.14
# Epoch 01343 | Time(s) 0.0052 | Loss 2.3846 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 163.16
# Epoch 01344 | Time(s) 0.0052 | Loss 60.4299 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 163.18
# Epoch 01345 | Time(s) 0.0052 | Loss 2.4784 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 163.20
# Epoch 01346 | Time(s) 0.0052 | Loss 1.9545 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 163.22
# Epoch 01347 | Time(s) 0.0052 | Loss 0.8550 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 163.24
# Epoch 01348 | Time(s) 0.0052 | Loss 1.0438 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 163.26
# Epoch 01349 | Time(s) 0.0052 | Loss 0.6793 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 163.28
# Epoch 01350 | Time(s) 0.0052 | Loss 1.1588 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 163.30
# Epoch 01351 | Time(s) 0.0052 | Loss 1.2892 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 163.32
# Epoch 01352 | Time(s) 0.0052 | Loss 0.7806 | TrainAcc 0.4000 | ValAcc 0.4667 | ETputs(KTEPS) 163.35
# Epoch 01353 | Time(s) 0.0052 | Loss 103.7119 | TrainAcc 0.6444 | ValAcc 0.4667 | ETputs(KTEPS) 163.37
# Epoch 01354 | Time(s) 0.0052 | Loss 0.6862 | TrainAcc 0.5556 | ValAcc 0.4444 | ETputs(KTEPS) 163.39
# Epoch 01355 | Time(s) 0.0052 | Loss 0.6534 | TrainAcc 0.4667 | ValAcc 0.4444 | ETputs(KTEPS) 163.41
# Epoch 01356 | Time(s) 0.0052 | Loss 0.8375 | TrainAcc 0.5111 | ValAcc 0.4000 | ETputs(KTEPS) 163.43
# Epoch 01357 | Time(s) 0.0052 | Loss 2.0680 | TrainAcc 0.5111 | ValAcc 0.4444 | ETputs(KTEPS) 163.45
# Epoch 01358 | Time(s) 0.0052 | Loss 0.6930 | TrainAcc 0.4889 | ValAcc 0.4444 | ETputs(KTEPS) 163.47
# Epoch 01359 | Time(s) 0.0052 | Loss 1.0410 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 163.50
# Epoch 01360 | Time(s) 0.0052 | Loss 0.6610 | TrainAcc 0.5333 | ValAcc 0.4889 | ETputs(KTEPS) 163.52
# Epoch 01361 | Time(s) 0.0052 | Loss 0.7930 | TrainAcc 0.5111 | ValAcc 0.4889 | ETputs(KTEPS) 163.54
# Epoch 01362 | Time(s) 0.0052 | Loss 0.8701 | TrainAcc 0.4889 | ValAcc 0.4889 | ETputs(KTEPS) 163.56
# Epoch 01363 | Time(s) 0.0052 | Loss 12.8552 | TrainAcc 0.5556 | ValAcc 0.4889 | ETputs(KTEPS) 163.58
# Epoch 01364 | Time(s) 0.0052 | Loss 1.4970 | TrainAcc 0.5778 | ValAcc 0.4889 | ETputs(KTEPS) 163.60
# Epoch 01365 | Time(s) 0.0052 | Loss 2.5706 | TrainAcc 0.5778 | ValAcc 0.4889 | ETputs(KTEPS) 163.62
# Epoch 01366 | Time(s) 0.0052 | Loss 0.6897 | TrainAcc 0.4889 | ValAcc 0.4889 | ETputs(KTEPS) 163.65
# Epoch 01367 | Time(s) 0.0052 | Loss 1.7382 | TrainAcc 0.4889 | ValAcc 0.4889 | ETputs(KTEPS) 163.66
# Epoch 01368 | Time(s) 0.0052 | Loss 0.8204 | TrainAcc 0.5111 | ValAcc 0.4889 | ETputs(KTEPS) 163.68
# Epoch 01369 | Time(s) 0.0052 | Loss 0.6506 | TrainAcc 0.4889 | ValAcc 0.4889 | ETputs(KTEPS) 163.70
# Epoch 01370 | Time(s) 0.0052 | Loss 0.6626 | TrainAcc 0.5778 | ValAcc 0.4889 | ETputs(KTEPS) 163.72
# Epoch 01371 | Time(s) 0.0052 | Loss 1.2741 | TrainAcc 0.4889 | ValAcc 0.4889 | ETputs(KTEPS) 163.74
# Epoch 01372 | Time(s) 0.0052 | Loss 16.8819 | TrainAcc 0.5778 | ValAcc 0.4889 | ETputs(KTEPS) 163.76
# Epoch 01373 | Time(s) 0.0052 | Loss 1.3322 | TrainAcc 0.5111 | ValAcc 0.4889 | ETputs(KTEPS) 163.79
# Epoch 01374 | Time(s) 0.0052 | Loss 4.6085 | TrainAcc 0.4667 | ValAcc 0.4889 | ETputs(KTEPS) 163.81
# Epoch 01375 | Time(s) 0.0052 | Loss 1.1539 | TrainAcc 0.4889 | ValAcc 0.4889 | ETputs(KTEPS) 163.83
# Epoch 01376 | Time(s) 0.0052 | Loss 0.6856 | TrainAcc 0.5333 | ValAcc 0.4889 | ETputs(KTEPS) 163.85
# Epoch 01377 | Time(s) 0.0052 | Loss 0.9165 | TrainAcc 0.5778 | ValAcc 0.4889 | ETputs(KTEPS) 163.87
# Epoch 01378 | Time(s) 0.0052 | Loss 0.6673 | TrainAcc 0.4889 | ValAcc 0.4889 | ETputs(KTEPS) 163.89
# Epoch 01379 | Time(s) 0.0052 | Loss 0.7993 | TrainAcc 0.5111 | ValAcc 0.5111 | ETputs(KTEPS) 163.91
# Epoch 01380 | Time(s) 0.0052 | Loss 0.6749 | TrainAcc 0.4667 | ValAcc 0.5111 | ETputs(KTEPS) 163.93
# Epoch 01381 | Time(s) 0.0052 | Loss 1.1944 | TrainAcc 0.5556 | ValAcc 0.4889 | ETputs(KTEPS) 163.95
# Epoch 01382 | Time(s) 0.0052 | Loss 0.6668 | TrainAcc 0.5111 | ValAcc 0.4889 | ETputs(KTEPS) 163.97
# Epoch 01383 | Time(s) 0.0052 | Loss 14.3898 | TrainAcc 0.4667 | ValAcc 0.4889 | ETputs(KTEPS) 163.99
# Epoch 01384 | Time(s) 0.0052 | Loss 0.7601 | TrainAcc 0.4889 | ValAcc 0.4444 | ETputs(KTEPS) 164.01
# Epoch 01385 | Time(s) 0.0052 | Loss 0.6953 | TrainAcc 0.5333 | ValAcc 0.4444 | ETputs(KTEPS) 164.03
# Epoch 01386 | Time(s) 0.0052 | Loss 0.9117 | TrainAcc 0.6000 | ValAcc 0.4444 | ETputs(KTEPS) 164.06
# Epoch 01387 | Time(s) 0.0052 | Loss 0.7534 | TrainAcc 0.5778 | ValAcc 0.4444 | ETputs(KTEPS) 164.08
# Epoch 01388 | Time(s) 0.0052 | Loss 1.7423 | TrainAcc 0.6222 | ValAcc 0.4444 | ETputs(KTEPS) 164.10
# Epoch 01389 | Time(s) 0.0052 | Loss 1.3114 | TrainAcc 0.5111 | ValAcc 0.4444 | ETputs(KTEPS) 164.12
# Epoch 01390 | Time(s) 0.0052 | Loss 1.2659 | TrainAcc 0.4667 | ValAcc 0.4444 | ETputs(KTEPS) 164.14
# Epoch 01391 | Time(s) 0.0052 | Loss 1.5098 | TrainAcc 0.5111 | ValAcc 0.4444 | ETputs(KTEPS) 164.16
# Epoch 01392 | Time(s) 0.0052 | Loss 0.8390 | TrainAcc 0.5778 | ValAcc 0.4444 | ETputs(KTEPS) 164.18
# Epoch 01393 | Time(s) 0.0052 | Loss 0.9465 | TrainAcc 0.5556 | ValAcc 0.4000 | ETputs(KTEPS) 164.20
# Epoch 01394 | Time(s) 0.0052 | Loss 6.0952 | TrainAcc 0.4889 | ValAcc 0.4000 | ETputs(KTEPS) 164.22
# Epoch 01395 | Time(s) 0.0052 | Loss 0.7161 | TrainAcc 0.4667 | ValAcc 0.3778 | ETputs(KTEPS) 164.24
# Epoch 01396 | Time(s) 0.0052 | Loss 0.8308 | TrainAcc 0.3556 | ValAcc 0.3778 | ETputs(KTEPS) 164.26
# Epoch 01397 | Time(s) 0.0051 | Loss 0.7199 | TrainAcc 0.4667 | ValAcc 0.4000 | ETputs(KTEPS) 164.28
# Epoch 01398 | Time(s) 0.0051 | Loss 0.6798 | TrainAcc 0.5778 | ValAcc 0.4000 | ETputs(KTEPS) 164.30
# Epoch 01399 | Time(s) 0.0051 | Loss 0.6779 | TrainAcc 0.6000 | ValAcc 0.4000 | ETputs(KTEPS) 164.32
# Epoch 01400 | Time(s) 0.0051 | Loss 0.6801 | TrainAcc 0.5778 | ValAcc 0.4000 | ETputs(KTEPS) 164.34
# Epoch 01401 | Time(s) 0.0051 | Loss 0.7258 | TrainAcc 0.5333 | ValAcc 0.4222 | ETputs(KTEPS) 164.36
# Epoch 01402 | Time(s) 0.0051 | Loss 0.7945 | TrainAcc 0.4889 | ValAcc 0.4222 | ETputs(KTEPS) 164.38
# Epoch 01403 | Time(s) 0.0051 | Loss 0.6831 | TrainAcc 0.6000 | ValAcc 0.4000 | ETputs(KTEPS) 164.41
# Epoch 01404 | Time(s) 0.0051 | Loss 0.6743 | TrainAcc 0.5778 | ValAcc 0.4222 | ETputs(KTEPS) 164.42
# Epoch 01405 | Time(s) 0.0051 | Loss 1.8024 | TrainAcc 0.4889 | ValAcc 0.4444 | ETputs(KTEPS) 164.44
# Epoch 01406 | Time(s) 0.0051 | Loss 0.7154 | TrainAcc 0.4889 | ValAcc 0.4444 | ETputs(KTEPS) 164.46
# Epoch 01407 | Time(s) 0.0051 | Loss 1.4040 | TrainAcc 0.5333 | ValAcc 0.4444 | ETputs(KTEPS) 164.48
# Epoch 01408 | Time(s) 0.0051 | Loss 0.7716 | TrainAcc 0.4222 | ValAcc 0.4444 | ETputs(KTEPS) 164.50
# Epoch 01409 | Time(s) 0.0051 | Loss 1.5906 | TrainAcc 0.3333 | ValAcc 0.4222 | ETputs(KTEPS) 164.52
# Epoch 01410 | Time(s) 0.0051 | Loss 0.6851 | TrainAcc 0.4889 | ValAcc 0.4000 | ETputs(KTEPS) 164.54
# Epoch 01411 | Time(s) 0.0051 | Loss 0.7901 | TrainAcc 0.4222 | ValAcc 0.4000 | ETputs(KTEPS) 164.56
# Epoch 01412 | Time(s) 0.0051 | Loss 0.8178 | TrainAcc 0.5111 | ValAcc 0.4000 | ETputs(KTEPS) 164.58
# Epoch 01413 | Time(s) 0.0051 | Loss 0.6565 | TrainAcc 0.4667 | ValAcc 0.4000 | ETputs(KTEPS) 164.60
# Epoch 01414 | Time(s) 0.0051 | Loss 0.6733 | TrainAcc 0.6222 | ValAcc 0.4222 | ETputs(KTEPS) 164.62
# Epoch 01415 | Time(s) 0.0051 | Loss 80.1044 | TrainAcc 0.4889 | ValAcc 0.4000 | ETputs(KTEPS) 164.64
# Epoch 01416 | Time(s) 0.0051 | Loss 1.0252 | TrainAcc 0.6000 | ValAcc 0.3778 | ETputs(KTEPS) 164.66
# Epoch 01417 | Time(s) 0.0051 | Loss 0.6803 | TrainAcc 0.4667 | ValAcc 0.4444 | ETputs(KTEPS) 164.68
# Epoch 01418 | Time(s) 0.0051 | Loss 0.9144 | TrainAcc 0.3333 | ValAcc 0.4667 | ETputs(KTEPS) 164.70
# Epoch 01419 | Time(s) 0.0051 | Loss 0.6906 | TrainAcc 0.5111 | ValAcc 0.4889 | ETputs(KTEPS) 164.72
# Epoch 01420 | Time(s) 0.0051 | Loss 0.6565 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 164.74
# Epoch 01421 | Time(s) 0.0051 | Loss 1.2939 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 164.76
# Epoch 01422 | Time(s) 0.0051 | Loss 0.8273 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 164.77
# Epoch 01423 | Time(s) 0.0051 | Loss 2.5011 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 164.79
# Epoch 01424 | Time(s) 0.0051 | Loss 0.7005 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 164.81
# Epoch 01425 | Time(s) 0.0051 | Loss 0.7975 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 164.83
# Epoch 01426 | Time(s) 0.0051 | Loss 1.2373 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 164.85
# Epoch 01427 | Time(s) 0.0051 | Loss 0.8091 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 164.87
# Epoch 01428 | Time(s) 0.0051 | Loss 0.8025 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 164.89
# Epoch 01429 | Time(s) 0.0051 | Loss 0.7415 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 164.91
# Epoch 01430 | Time(s) 0.0051 | Loss 0.6485 | TrainAcc 0.6000 | ValAcc 0.5333 | ETputs(KTEPS) 164.93
# Epoch 01431 | Time(s) 0.0051 | Loss 0.6949 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 164.95
# Epoch 01432 | Time(s) 0.0051 | Loss 7.4198 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 164.96
# Epoch 01433 | Time(s) 0.0051 | Loss 0.6617 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 164.98
# Epoch 01434 | Time(s) 0.0051 | Loss 0.8984 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 165.00
# Epoch 01435 | Time(s) 0.0051 | Loss 1.4670 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 165.02
# Epoch 01436 | Time(s) 0.0051 | Loss 1.5288 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 165.04
# Epoch 01437 | Time(s) 0.0051 | Loss 0.6669 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 165.06
# Epoch 01438 | Time(s) 0.0051 | Loss 0.6934 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 165.08
# Epoch 01439 | Time(s) 0.0051 | Loss 3.3434 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 165.10
# Epoch 01440 | Time(s) 0.0051 | Loss 0.7843 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 165.12
# Epoch 01441 | Time(s) 0.0051 | Loss 0.6658 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 165.14
# Epoch 01442 | Time(s) 0.0051 | Loss 0.9237 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 165.16
# Epoch 01443 | Time(s) 0.0051 | Loss 1.1210 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 165.17
# Epoch 01444 | Time(s) 0.0051 | Loss 0.6877 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 165.19
# Epoch 01445 | Time(s) 0.0051 | Loss 0.6728 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 165.21
# Epoch 01446 | Time(s) 0.0051 | Loss 0.6623 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 165.23
# Epoch 01447 | Time(s) 0.0051 | Loss 1.2867 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 165.25
# Epoch 01448 | Time(s) 0.0051 | Loss 0.7280 | TrainAcc 0.4222 | ValAcc 0.5333 | ETputs(KTEPS) 165.26
# Epoch 01449 | Time(s) 0.0051 | Loss 1.2017 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 165.28
# Epoch 01450 | Time(s) 0.0051 | Loss 1.1110 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 165.30
# Epoch 01451 | Time(s) 0.0051 | Loss 0.6484 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 165.32
# Epoch 01452 | Time(s) 0.0051 | Loss 0.6823 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 165.34
# Epoch 01453 | Time(s) 0.0051 | Loss 0.8806 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 165.36
# Epoch 01454 | Time(s) 0.0051 | Loss 1.5633 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 165.38
# Epoch 01455 | Time(s) 0.0051 | Loss 0.7175 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 165.39
# Epoch 01456 | Time(s) 0.0051 | Loss 76.2722 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 165.41
# Epoch 01457 | Time(s) 0.0051 | Loss 0.6699 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 165.43
# Epoch 01458 | Time(s) 0.0051 | Loss 0.6809 | TrainAcc 0.4222 | ValAcc 0.5333 | ETputs(KTEPS) 165.45
# Epoch 01459 | Time(s) 0.0051 | Loss 2.2212 | TrainAcc 0.6000 | ValAcc 0.5333 | ETputs(KTEPS) 165.47
# Epoch 01460 | Time(s) 0.0051 | Loss 0.8479 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 165.49
# Epoch 01461 | Time(s) 0.0051 | Loss 0.7030 | TrainAcc 0.5778 | ValAcc 0.5778 | ETputs(KTEPS) 165.51
# Epoch 01462 | Time(s) 0.0051 | Loss 0.8741 | TrainAcc 0.4667 | ValAcc 0.6444 | ETputs(KTEPS) 165.53
# Epoch 01463 | Time(s) 0.0051 | Loss 0.7279 | TrainAcc 0.4667 | ValAcc 0.5778 | ETputs(KTEPS) 165.54
# Epoch 01464 | Time(s) 0.0051 | Loss 0.7781 | TrainAcc 0.5333 | ValAcc 0.6222 | ETputs(KTEPS) 165.56
# Epoch 01465 | Time(s) 0.0051 | Loss 294.9608 | TrainAcc 0.5556 | ValAcc 0.5778 | ETputs(KTEPS) 165.58
# Epoch 01466 | Time(s) 0.0051 | Loss 0.9180 | TrainAcc 0.5333 | ValAcc 0.5111 | ETputs(KTEPS) 165.60
# Epoch 01467 | Time(s) 0.0051 | Loss 1.0344 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 165.61
# Epoch 01468 | Time(s) 0.0051 | Loss 0.9771 | TrainAcc 0.3778 | ValAcc 0.4667 | ETputs(KTEPS) 165.63
# Epoch 01469 | Time(s) 0.0051 | Loss 0.6809 | TrainAcc 0.3778 | ValAcc 0.4667 | ETputs(KTEPS) 165.65
# Epoch 01470 | Time(s) 0.0051 | Loss 1.1689 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 165.67
# Epoch 01471 | Time(s) 0.0051 | Loss 0.9282 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 165.68
# Epoch 01472 | Time(s) 0.0051 | Loss 0.6799 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 165.70
# Epoch 01473 | Time(s) 0.0051 | Loss 0.7006 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 165.72
# Epoch 01474 | Time(s) 0.0051 | Loss 1.0120 | TrainAcc 0.6000 | ValAcc 0.4667 | ETputs(KTEPS) 165.74
# Epoch 01475 | Time(s) 0.0051 | Loss 1.1290 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 165.76
# Epoch 01476 | Time(s) 0.0051 | Loss 1.4595 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 165.78
# Epoch 01477 | Time(s) 0.0051 | Loss 5.5252 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 165.80
# Epoch 01478 | Time(s) 0.0051 | Loss 0.8771 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 165.82
# Epoch 01479 | Time(s) 0.0051 | Loss 0.7429 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 165.83
# Epoch 01480 | Time(s) 0.0051 | Loss 0.6742 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 165.85
# Epoch 01481 | Time(s) 0.0051 | Loss 1.1326 | TrainAcc 0.5556 | ValAcc 0.4222 | ETputs(KTEPS) 165.87
# Epoch 01482 | Time(s) 0.0051 | Loss 0.6933 | TrainAcc 0.6222 | ValAcc 0.3556 | ETputs(KTEPS) 165.89
# Epoch 01483 | Time(s) 0.0051 | Loss 0.8562 | TrainAcc 0.4889 | ValAcc 0.3111 | ETputs(KTEPS) 165.91
# Epoch 01484 | Time(s) 0.0051 | Loss 1.2838 | TrainAcc 0.5111 | ValAcc 0.3556 | ETputs(KTEPS) 165.93
# Epoch 01485 | Time(s) 0.0051 | Loss 0.6804 | TrainAcc 0.5111 | ValAcc 0.4000 | ETputs(KTEPS) 165.94
# Epoch 01486 | Time(s) 0.0051 | Loss 0.8929 | TrainAcc 0.4000 | ValAcc 0.4000 | ETputs(KTEPS) 165.95
# Epoch 01487 | Time(s) 0.0051 | Loss 1.0024 | TrainAcc 0.5778 | ValAcc 0.4000 | ETputs(KTEPS) 165.96
# Epoch 01488 | Time(s) 0.0051 | Loss 3.1190 | TrainAcc 0.5333 | ValAcc 0.4000 | ETputs(KTEPS) 165.98
# Epoch 01489 | Time(s) 0.0051 | Loss 0.7168 | TrainAcc 0.4222 | ValAcc 0.3778 | ETputs(KTEPS) 166.00
# Epoch 01490 | Time(s) 0.0051 | Loss 1.0323 | TrainAcc 0.5556 | ValAcc 0.4000 | ETputs(KTEPS) 166.02
# Epoch 01491 | Time(s) 0.0051 | Loss 0.7702 | TrainAcc 0.5111 | ValAcc 0.4000 | ETputs(KTEPS) 166.04
# Epoch 01492 | Time(s) 0.0051 | Loss 0.6514 | TrainAcc 0.6222 | ValAcc 0.4000 | ETputs(KTEPS) 166.05
# Epoch 01493 | Time(s) 0.0051 | Loss 0.6638 | TrainAcc 0.4667 | ValAcc 0.4000 | ETputs(KTEPS) 166.07
# Epoch 01494 | Time(s) 0.0051 | Loss 1.2385 | TrainAcc 0.4889 | ValAcc 0.4000 | ETputs(KTEPS) 166.09
# Epoch 01495 | Time(s) 0.0051 | Loss 1.1595 | TrainAcc 0.4667 | ValAcc 0.3778 | ETputs(KTEPS) 166.10
# Epoch 01496 | Time(s) 0.0051 | Loss 0.6917 | TrainAcc 0.5111 | ValAcc 0.3778 | ETputs(KTEPS) 166.12
# Epoch 01497 | Time(s) 0.0051 | Loss 0.7122 | TrainAcc 0.5556 | ValAcc 0.4000 | ETputs(KTEPS) 166.14
# Epoch 01498 | Time(s) 0.0051 | Loss 174.8244 | TrainAcc 0.4667 | ValAcc 0.4000 | ETputs(KTEPS) 166.16
# Epoch 01499 | Time(s) 0.0051 | Loss 0.7440 | TrainAcc 0.5778 | ValAcc 0.4222 | ETputs(KTEPS) 166.18
# Time per epoch:  0.005090938886006673

# %% [markdown]
# Test Model Accuracy

# %%
acc, _ = evaluate(model,features, labels, test_mask, loss_fcn)
print("Test Accuracy {:.4f}".format(acc))
# Out:
# Test Accuracy 0.4167

# %% [markdown]
# Calculating Mean and Standard Deviation

# %%
a= [0.5676,0.2973,0.2973]
mean_a = np.mean(a)
std_dev_a = np.std(a)
print(mean_a, std_dev_a)
# Out:
# 0.38739999999999997 0.12742064196981587

# %%
import sys
from pathlib import Path

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import torch

# Font + global sizing
font_dir = Path.home() / '.local' / 'share' / 'fonts' / 'msttcore'
font_paths = []
if font_dir.exists():
    font_paths = list(font_dir.glob('*.ttf')) + list(font_dir.glob('*.TTF'))
    for font_path in font_paths:
        fm.fontManager.addfont(str(font_path))

font_name = None
if font_paths:
    font_name = fm.FontProperties(fname=str(font_paths[0])).get_name()

if font_name:
    mpl.rcParams['font.family'] = font_name
    mpl.rcParams['font.serif'] = [font_name, 'Times New Roman', 'Times', 'DejaVu Serif']
else:
    mpl.rcParams['font.family'] = 'serif'
    mpl.rcParams['font.serif'] = ['Times New Roman', 'Times', 'DejaVu Serif']

FIGSIZE = (7, 6)
mpl.rcParams['figure.figsize'] = FIGSIZE

root_dir = Path.cwd()
if not (root_dir / 'visualization_utils').exists() and (root_dir.parent / 'visualization_utils').exists():
    sys.path.insert(0, str(root_dir.parent))

from visualization_utils.graph import (
    compute_graph_layout,
    count_edges_with_different_labels,
    plot_graph_two_class,
    visualize_graphs_side_by_side,
)
from visualization_utils.embeddings import (
    extract_embeddings,
    reduce_embeddings_2d,
    plot_embeddings_2d,
)
from visualization_utils.io import ensure_dir, save_figure
from visualization_utils.utils import select_two_classes

# %%
def topk_per_neighbor(edge_index: torch.Tensor,
                      edge_weight: torch.Tensor,
                      frac: float = 0.2,
                      num_nodes: int | None = None,
                      min_k: int = 1) -> torch.Tensor:
    """
    Select top frac of outgoing edges for each source node (row of edge_index),
    based on edge_weight. Returns sampled_edge_index [2, E'].
    """
    assert edge_index.dim() == 2 and edge_index.size(0) == 2
    assert edge_weight.dim() == 1 and edge_weight.numel() == edge_index.size(1)

    row = edge_index[0]
    E = edge_weight.numel()

    if num_nodes is None:
        num_nodes = int(row.max().item()) + 1 if E > 0 else 0

    # degrees per source node
    deg = torch.bincount(row, minlength=num_nodes)  # [N]
    # top-k per node = max(min_k, ceil(frac * deg))
    k = torch.ceil(deg.float() * frac).long().clamp(min=min_k)  # [N]

    # ---- sort edges by (row asc, weight desc within row) ----
    # 1) sort by weight desc
    perm_w = torch.argsort(edge_weight, descending=True)
    row_w = row[perm_w]

    # 2) stable sort by row so weight order is preserved within each row group
    perm_r = torch.argsort(row_w, stable=True)
    perm = perm_w[perm_r]  # final permutation

    row_s = row[perm]

    # position of each edge inside its row-group after sorting (0,1,2,...)
    is_new_group = torch.ones_like(row_s, dtype=torch.bool)
    is_new_group[1:] = row_s[1:] != row_s[:-1]
    group_id = torch.cumsum(is_new_group.long(), dim=0) - 1  # [E], 0..G-1

    # index of first occurrence per group
    first_idx = torch.full((int(group_id.max().item()) + 1,), -1, device=row.device, dtype=torch.long)
    first_idx[group_id[is_new_group]] = torch.nonzero(is_new_group, as_tuple=False).view(-1)

    # pos_in_group = arange(E) - first_idx[group_id]
    ar = torch.arange(row_s.size(0), device=row.device)
    pos_in_group = ar - first_idx[group_id]

    # keep if pos_in_group < k[src_node]
    keep = pos_in_group < k[row_s]

    sampled_edge_index = edge_index[:, perm[keep]]
    return sampled_edge_index


# # ---- usage ----
# edge_index_all, edge_weights = get_sparsegat_edge_weights(model)

# %%
# SparseGAT visualization helpers

def get_sparsegat_edge_weights(model):
    model.eval()
    with torch.no_grad():
        _ = model(features)
    g_local = model.gat_layers[0].g
    att = g_local.edata['a']
    weights = att.view(-1).detach().cpu()
    src, dst = g_local.edges()
    edge_index = torch.stack([src, dst], dim=0).cpu()
    return edge_index, weights


def get_sparsegat_embeddings(model):
    model.eval()
    with torch.no_grad():
        h = features
        edges = "__ALL__"
        h, edges = model.gat_layers[0](h, edges)
        h = model.activation(h.flatten(1))
        for l in range(1, model.num_layers):
            h, _ = model.gat_layers[l](h, edges, skip=1)
            h = model.activation(h.flatten(1))
    return h.detach().cpu()

# Paper-ready figures (SparseGAT)
fig_dir = ensure_dir('KDDFigures')
class_pair = select_two_classes(data.y, None)

edge_index_all, edge_weights = get_sparsegat_edge_weights(model)
# num_edges = edge_weights.numel()
# top_k = max(1, int(0.2 * num_edges))
# top_idx = torch.topk(edge_weights, top_k).indices
# sampled_edge_index = edge_index_all[:, top_idx]

sampled_edge_index = topk_per_neighbor(
    edge_index_all,
    edge_weights,
    frac=0.2,      # top 20% per node
    num_nodes=data.num_nodes,  # recommended if you have it
    min_k=1
)

pos = compute_graph_layout(data, dataset_name=DATASET_NAME, seed=42)

fig_full, ax_full = plt.subplots(figsize=FIGSIZE)
plot_graph_two_class(
    data,
    ax=ax_full,
    pos=pos,
    class_pair=class_pair,
    dataset_name=DATASET_NAME,
#     title='Original dense graph (SparseGAT)',
    node_size=50,
    highlight_colors=('blue', 'red'),
)
save_figure(fig_full, fig_dir / 'SparseGATOriginalGraph.pdf', dpi=300)

fig_sparse, ax_sparse = plt.subplots(figsize=FIGSIZE)
plot_graph_two_class(
    data,
    edge_index=sampled_edge_index,
    ax=ax_sparse,
    pos=pos,
    class_pair=class_pair,
    dataset_name=DATASET_NAME,
#     title='SparseGAT subgraph (top 20%)',
    node_size=50,
    highlight_colors=('blue', 'red'),
)
save_figure(fig_sparse, fig_dir / 'SparseGATSparseGraph.pdf', dpi=300)

embeddings = get_sparsegat_embeddings(model)
emb_2d = reduce_embeddings_2d(embeddings, method='pca', random_state=42)
fig_emb, ax_emb = plt.subplots(figsize=FIGSIZE)
plot_embeddings_2d(
    emb_2d,
    data.y,
    class_pair=class_pair,
    ax=ax_emb,
#     title='SparseGAT embeddings (PCA)',
    highlight_colors=('blue', 'red'),
)
save_figure(fig_emb, fig_dir / 'SparseGATEmbedding.pdf', dpi=300)

plt.show()

# %%
result  = count_edges_with_different_labels(data, sampled_edge_index)
print(f"Original graph: {result['original_graph']['different_label_edges']} edges with different labels "
              f"out of {result['original_graph']['total_edges']} total edges "
              f"(Edge homophily: {100-result['original_graph']['percentage']:.2f}%).")

print(f"Sampled graph: {result['sampled_graph']['different_label_edges']} edges with different labels "
      f"out of {result['sampled_graph']['total_edges']} total edges "
      f"(Edge homophily: {100-result['sampled_graph']['percentage']:.2f}%).")
# Out:
# Original graph: 570 edges with different labels out of 846 total edges (Edge homophily: 32.62%).
# Sampled graph: 146 edges with different labels out of 226 total edges (Edge homophily: 35.40%).
